# %% [markdown]
# # Data Inspection

# %%
import pandas as pd

# %% [markdown]
# ## 🔹 Basic Inspection

# %% [markdown]
# #### 1. Load a CSV file and display first 10 rows

# %%
data = pd.read_csv('Sale.csv')

# %%
data.head(10)
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# 5     10457  08-11-2022               Fries   3.49    573.07     In-store
# 6     10459  08-11-2022       Sides & Other   4.99    200.40     In-store
# 7     10460  09-11-2022             Burgers  12.99    554.27     In-store
# 8     10461  09-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# 9     10462  09-11-2022               Fries   3.49    573.07     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# ...

# %% [markdown]
# #### 2. Show last 5 rows of dataset

# %%
data.tail()
# Out:
#      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 249     10709  28-12-2022       Sides & Other   4.99    200.40   Drive-thru
# 250     10710  29-12-2022             Burgers  12.99    754.43   Drive-thru
# 251     10711  29-12-2022  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712  29-12-2022               Fries   3.49    630.37   Drive-thru
# 253     10713  29-12-2022           Beverages   2.95    677.97   Drive-thru
#
#     Payment Method        Manager    City
# 249      Gift Card  Walter Muller  Berlin
# 250      Gift Card  Walter Muller  Berlin
# 251      Gift Card  Walter Muller  Berlin
# 252      Gift Card  Walter Muller  Berlin
# 253      Gift Card  Walter Muller  Berlin

# %% [markdown]
# #### 3. Find total number of rows and columns

# %%
rows , cols = data.shape
print("Total Rows :",rows)
print("Total columns :",cols)
# Out:
# Total Rows : 254
# Total columns : 9

# %% [markdown]
# #### 4. Display column names

# %%
print(data.columns)
# Out:
# Index(['Order ID', 'Date', 'Product', 'Price', 'Quantity', 'Purchase Type',
#        'Payment Method', 'Manager', 'City'],
#       dtype='object')

# %% [markdown]
# #### 5. Check data types of each column

# %%
data.dtypes
# Out:
# Order ID            int64
# Date               object
# Product            object
# Price             float64
# Quantity          float64
# Purchase Type      object
# Payment Method     object
# Manager            object
# City               object
# dtype: object

# %% [markdown]
# #### 6. Get summary statistics of numerical columns

# %%
data.describe()
# Out:
#            Order ID       Price    Quantity
# count    254.000000  254.000000  254.000000
# mean   10584.133858    7.102323  460.611457
# std       75.889181    4.341855  214.888699
# min    10452.000000    2.950000  200.400000
# 25%    10520.250000    3.490000  201.010000
# 50%    10583.500000    4.990000  538.880000
# 75%    10649.750000    9.950000  677.440000
# max    10713.000000   29.050000  754.430000

# %% [markdown]
# #### 7. Get summary of all columns (including object type)

# %%
data.describe(include='all')
# Out:
#             Order ID        Date             Product       Price    Quantity  \
# count     254.000000         254                 254  254.000000  254.000000
# unique           NaN          53                   5         NaN         NaN
# top              NaN  09-11-2022  Chicken Sandwiches         NaN         NaN
# freq             NaN           5                  52         NaN         NaN
# mean    10584.133858         NaN                 NaN    7.102323  460.611457
# std        75.889181         NaN                 NaN    4.341855  214.888699
# min     10452.000000         NaN                 NaN    2.950000  200.400000
# 25%     10520.250000         NaN                 NaN    3.490000  201.010000
# 50%     10583.500000         NaN                 NaN    4.990000  538.880000
# 75%     10649.750000         NaN                 NaN    9.950000  677.440000
# max     10713.000000         NaN                 NaN   29.050000  754.430000
#
# ...

# %% [markdown]
# #### 8. Find memory usage of dataset

# %%
data.memory_usage()
# Out:
# Index              132
# Order ID          2032
# Date              2032
# Product           2032
# Price             2032
# Quantity          2032
# Purchase Type     2032
# Payment Method    2032
# Manager           2032
# City              2032
# dtype: int64

# %%
data.memory_usage(deep=True)
# Out:
# Index               132
# Order ID           2032
# Date              14986
# Product           15088
# Price              2032
# Quantity           2032
# Purchase Type     14640
# Payment Method    14846
# Manager           15293
# City              13942
# dtype: int64

# %% [markdown]
# ## 🔹 Understanding Data Quality

# %% [markdown]
# #### 9. Identify columns with missing values

# %%
data.isnull()
# Out:
#      Order ID   Date  Product  Price  Quantity  Purchase Type  Payment Method  \
# 0       False  False    False  False     False          False           False
# 1       False  False    False  False     False          False           False
# 2       False  False    False  False     False          False           False
# 3       False  False    False  False     False          False           False
# 4       False  False    False  False     False          False           False
# ..        ...    ...      ...    ...       ...            ...             ...
# 249     False  False    False  False     False          False           False
# 250     False  False    False  False     False          False           False
# 251     False  False    False  False     False          False           False
# 252     False  False    False  False     False          False           False
# 253     False  False    False  False     False          False           False
#
#      Manager   City
# ...

# %%
data.columns[data.isnull().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# #

# %%
data2 = pd.read_csv("Dataset2.csv")

# %%
data2.head()
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.6
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
# 4         0    137.0          40.0       35.0          168.0  43.1
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1

# %%
data2.columns[data2.isnull().any()]
# Out:
# Index(['Glucose', 'Diastolic_BP', 'Skin_Fold', 'Serum_Insulin', 'BMI'], dtype='object')

# %% [markdown]
# #### 10. Count total missing values in dataset

# %%
data2.isnull().sum()
# Out:
# Pregnant               0
# Glucose                5
# Diastolic_BP          35
# Skin_Fold            227
# Serum_Insulin        374
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64

# %%
data2.isnull().sum().sum()
# Out:
# np.int64(652)

# %% [markdown]
# #### 11. Find percentage of missing values per column

# %%
missing_per = round((data2.isnull().sum() /len(data2))*100)

# %%
missing_per
# Out:
# Pregnant              0.0
# Glucose               1.0
# Diastolic_BP          5.0
# Skin_Fold            30.0
# Serum_Insulin        49.0
# BMI                   1.0
# Diabetes_Pedigree     0.0
# Age                   0.0
# Class                 0.0
# dtype: float64

# %%
round((data2.isnull().mean() * 100))
# Out:
# Pregnant              0.0
# Glucose               1.0
# Diastolic_BP          5.0
# Skin_Fold            30.0
# Serum_Insulin        49.0
# BMI                   1.0
# Diabetes_Pedigree     0.0
# Age                   0.0
# Class                 0.0
# dtype: float64

# %% [markdown]
# #### 12. Check if dataset has any null values (True/False)

# %%
data2.isnull().any()
# Out:
# Pregnant             False
# Glucose               True
# Diastolic_BP          True
# Skin_Fold             True
# Serum_Insulin         True
# BMI                   True
# Diabetes_Pedigree    False
# Age                  False
# Class                False
# dtype: bool

# %%
data2.isnull().values.any()
# Out:
# np.True_

# %%
data.isnull().values.any()
# Out:
# np.False_

# %%
data2.isnull().any().any()
# Out:
# np.True_

# %% [markdown]
# #### 13. Identify column with maximum missing data

# %%
data.isnull().sum().idxmax()
# Out:
# 'Order ID'

# %%
data2.isnull().sum().idxmax()
# Out:
# 'Serum_Insulin'

# %% [markdown]
# ## 🔹 Unique & Value Analysis

# %% [markdown]
# #### 14. Find unique values in a column

# %%
data.columns
# Out:
# Index(['Order ID', 'Date', 'Product', 'Price', 'Quantity', 'Purchase Type',
#        'Payment Method', 'Manager', 'City'],
#       dtype='object')

# %%
data['Product'].unique()
# Out:
# array(['Fries', 'Beverages', 'Sides & Other', 'Burgers',
#        'Chicken Sandwiches'], dtype=object)

# %%
data.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16500\354339855.py in ?()
# ----> 1 data.unique()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %% [markdown]
# #### 15. Count number of unique values in each column

# %%
data.nunique()
# Out:
# Order ID          254
# Date               53
# Product             5
# Price               7
# Quantity           29
# Purchase Type       3
# Payment Method      3
# Manager            14
# City                5
# dtype: int64

# %% [markdown]
# #### 16. Find most frequent value in a column

# %%
data["Product"].idxmax() # wrong
# Out:
# 2

# %%
data['Product'].mode()
# Out:
# 0               Burgers
# 1    Chicken Sandwiches
# Name: Product, dtype: object

# %%
data['Product'].mode()[0]
# Out:
# 'Burgers'

# %% [markdown]
# #### 17. Display frequency count of a categorical column

# %%
data['Product'].value_counts()
# Out:
# Product
# Chicken Sandwiches    52
# Burgers               52
# Fries                 51
# Beverages             50
# Sides & Other         49
# Name: count, dtype: int64

# %% [markdown]
# #### 18. Identify columns with only one unique value

# %%
data.nunique()[data.nunique() == 1]
# Out:
# Series([], dtype: int64)

# %%
data.columns[data.nunique() == 1]
# Out:
# Index([], dtype='object')

# %%
import numpy as np

# %%
dict_data = {
    "A" :  np.full(5,1),
    "B" : np.random.random(5),
    "C" : np.random.rand(5)
}
df = pd.DataFrame(dict_data)

# %%
df.nunique()[df.nunique() == 1]
# Out:
# A    1
# dtype: int64

# %%
df.columns[df.nunique()==1]
# Out:
# Index(['A'], dtype='object')

# %% [markdown]
# ## 🔹 Duplicate & Consistency Check

# %% [markdown]
# #### 19. Check total duplicate rows

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data2.duplicated().sum()
# Out:
# np.int64(0)

# %%
data3 =  pd.read_csv("dataset3.csv")

# %%
data3.duplicated().sum()
# Out:
# np.int64(3)

# %% [markdown]
# #### 20. Show duplicate rows

# %%
data3[data3.duplicated()]
# Out:
#     id  name   age   city   salary
# 5    3  Sita  20.0  Delhi  20000.0
# 15   3  Sita  20.0  Delhi  20000.0
# 25  11  John  22.0   Pune  50000.0

# %% [markdown]
# #### 21. Identify duplicate values in a specific column

# %%
data3.columns
# Out:
# Index(['id', 'name', 'age', 'city', 'salary'], dtype='object')

# %%
data3['name'].duplicated().sum()
# Out:
# np.int64(94)

# %%
data3['city'].duplicated().sum()
# Out:
# np.int64(94)

# %%
data3['name']
# Out:
# 0     John
# 1     Neha
# 2     Sita
# 3     Neha
# 4     Neha
#       ...
# 95    John
# 96    John
# 97    Neha
# 98    Amit
# 99    Neha
# Name: name, Length: 100, dtype: object

# %%
data3['name'].nunique()
# Out:
# 6

# %% [markdown]
# ## 🔹 Data Distribution Understanding

# %% [markdown]
# #### 22. Find min, max, mean of a column

# %%
data3.describe()
# Out:
#                id        age        salary
# count  100.000000  85.000000     82.000000
# mean    50.190000  21.858824  33414.634146
# std     29.407858   1.456945  11463.254466
# min      1.000000  20.000000  20000.000000
# 25%     24.750000  20.000000  20000.000000
# 50%     50.500000  22.000000  30000.000000
# 75%     75.250000  23.000000  40000.000000
# max    100.000000  24.000000  50000.000000

# %%
data3['age'].min()
# Out:
# 20.0

# %%
data3['age'].max()
# Out:
# 24.0

# %%
print(np.round(data3['age'].mean()))
# Out:
# 22.0

# %% [markdown]
# #### 23. Identify column with highest average value`

# %%
data3.mean().idxmax()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 data3.mean().idxmax()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
# ...

# %%
data3.mean(numeric_only=True).idxmax()
# Out:
# 'salary'

# %% [markdown]
# #### 24. Check standard deviation of numerical columns

# %%
data3.std(numeric_only=True)
# Out:
# id           29.407858
# age           1.456945
# salary    11463.254466
# dtype: float64

# %% [markdown]
# #### 25. Find skewness of data

# %%
data3.skew(numeric_only=True)
# Out:
# id       -0.021259
# age       0.038463
# salary    0.199098
# dtype: float64

# %% [markdown]
# ## 🔹 Column-wise Deep Inspection

# %% [markdown]
# #### 26. Inspect a single column completely

# %%
data.columns
# Out:
# Index(['Order ID', 'Date', 'Product', 'Price', 'Quantity', 'Purchase Type',
#        'Payment Method', 'Manager', 'City'],
#       dtype='object')

# %%
data['Product'].describe()
# Out:
# count                    254
# unique                     5
# top       Chicken Sandwiches
# freq                      52
# Name: Product, dtype: object

# %%
data['Purchase Type'].describe()
# Out:
# count         254
# unique          3
# top       Online
# freq          107
# Name: Purchase Type, dtype: object

# %% [markdown]
# #### 27.Check datatype + null + unique values of one column

# %%
data3.columns
# Out:
# Index(['id', 'name', 'age', 'city', 'salary'], dtype='object')

# %%
data3['age'].dtype
# Out:
# dtype('float64')

# %%
data3['age'].isnull().sum()
# Out:
# np.int64(15)

# %%
data3['age'].unique()
# Out:
# array([24., 20., 22., 21., 23., nan])

# %% [markdown]
# #### 28. Find columns with numeric data only

# %%
data3.select_dtypes(include='number').columns
# Out:
# Index(['id', 'age', 'salary'], dtype='object')

# %% [markdown]
# #### 29. Find columns with object/string type

# %%
data3.select_dtypes(include='object').columns
# Out:
# Index(['name', 'city'], dtype='object')
