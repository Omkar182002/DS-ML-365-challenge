# %% [markdown]
# # Data Cleaning Practice 3

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv('messy_data2.csv')

# %%
df = data.copy(deep=True)

# %% [markdown]
# #

# %% [markdown]
# # Data Inspection

# %%
df.head()
# Out:
#   Employee_ID           Name    Age   Salary Department       City  \
# 0     EMP1000  Yasmin Thakur    NaN      NaN    Support  Bangalore
# 1         NaN         Stuvan  150.0  unknown  Marketing      Delhi
# 2     EMP1002            NaN   -5.0   -10000        NaN  Bangalore
# 3         NaN    Yuvaan Raju    NaN    90861        NaN     Mumbai
# 4         NaN            NaN   59.0      NaN         HR       Pune
#
#                                Email  Phone_Number   Join_Date  \
# 0                  wthaker@yahoo.com           NaN  2022-01-30
# 1  umangbalakrishnan@viswanathan.biz  1.234500e+04         NaN
# 2                                NaN  4.470941e+09  32-13-2023
# 3             venkateshpihu@dash.com           NaN  32-13-2023
# 4                                NaN  1.000000e+15         NaN
#
#    Experience_Years  Performance_Score  Gender
# 0               0.4               10.0     NaN
# 1               NaN                2.0   Other
# ...

# %%
df.tail()
# Out:
#     Employee_ID        Name    Age   Salary Department       City  \
# 995     EMP1067         NaN   -5.0  unknown    Finance        NaN
# 996     EMP1996        Pari  150.0      NaN         HR  Bangalore
# 997     EMP1099         NaN    NaN      NaN        NaN  Bangalore
# 998     EMP1998     Nishith  150.0      NaN         HR        NaN
# 999         NaN  Gokul Kota  150.0    50626    Finance       Pune
#
#              Email  Phone_Number   Join_Date  Experience_Years  \
# 995  invalid_email  1.234500e+04  32-13-2023              -3.0
# 996  invalid_email  1.903628e+09  2024-06-05               NaN
# 997   pranay@gmail  1.234500e+04  32-13-2023               7.7
# 998   kartik@gmail  1.000000e+15  32-13-2023               3.7
# 999            NaN           NaN         NaN               NaN
#
#      Performance_Score  Gender
# 995                1.0    Male
# 996               10.0    Male
# 997               10.0    Male
# 998               10.0  Female
# ...

# %%
 df.sample(10)
# Out:
#     Employee_ID       Name    Age   Salary Department       City  \
# 666     EMP1053        NaN    NaN   -10000    Support  Hyderabad
# 494     EMP1494   Parinaaz  150.0   -10000         IT  Bangalore
# 311         NaN        NaN   22.0   -10000         HR      Delhi
# 211     EMP1067     Akarsh   28.0      NaN    Finance  Hyderabad
# 189     EMP1189      Taran   -5.0      NaN      Sales  Hyderabad
# 278         NaN        NaN    NaN   -10000      Sales     Mumbai
# 448     EMP1448      Aarav  150.0   -10000        NaN        NaN
# 554     EMP1026        NaN   53.0      NaN  Marketing        NaN
# 292         NaN  Diya Dhar   54.0  unknown    Support     Mumbai
# 681     EMP1681     Jayesh   -5.0      NaN         IT      Delhi
#
#                      Email  Phone_Number   Join_Date  Experience_Years  \
# 666                    NaN  9.128980e+11         NaN              -3.0
# 494                    NaN           NaN  32-13-2023              -3.0
# ...

# %% [markdown]
# #

# %%
df.dtypes
# Out:
# Employee_ID           object
# Name                  object
# Age                  float64
# Salary                object
# Department            object
# City                  object
# Email                 object
# Phone_Number         float64
# Join_Date             object
# Experience_Years     float64
# Performance_Score    float64
# Gender                object
# dtype: object

# %%
df.describe()
# Out:
#               Age  Phone_Number  Experience_Years  Performance_Score
# count  765.000000  7.570000e+02        647.000000         652.000000
# mean    67.067974  3.409361e+14          1.887326           6.450920
# std     66.675098  4.742139e+14          6.083940           3.653467
# min     -5.000000  1.234500e+04         -3.000000           1.000000
# 25%     -5.000000  1.234500e+04         -3.000000           3.000000
# 50%     44.000000  8.513171e+09         -3.000000           5.000000
# 75%    150.000000  1.000000e+15          7.500000          10.000000
# max    150.000000  1.000000e+15         14.900000          10.000000

# %%
df.isnull().sum()
# Out:
# Employee_ID          329
# Name                 499
# Age                  235
# Salary               264
# Department           143
# City                 143
# Email                283
# Phone_Number         243
# Join_Date            321
# Experience_Years     353
# Performance_Score    348
# Gender               417
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Employee_ID          32.9
# Name                 49.9
# Age                  23.5
# Salary               26.4
# Department           14.3
# City                 14.3
# Email                28.3
# Phone_Number         24.3
# Join_Date            32.1
# Experience_Years     35.3
# Performance_Score    34.8
# Gender               41.7
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Employee_ID'].duplicated().sum()
# Out:
# np.int64(584)

# %%
df[df['Employee_ID'].duplicated()]
# Out:
#     Employee_ID           Name    Age   Salary Department       City  \
# 3           NaN    Yuvaan Raju    NaN    90861        NaN     Mumbai
# 4           NaN            NaN   59.0      NaN         HR       Pune
# 8           NaN            NaN    NaN   148085        NaN    Chennai
# 12          NaN            NaN    NaN      NaN        NaN       Pune
# 13          NaN  Lakshit Bajwa   59.0  unknown    Support      Delhi
# ..          ...            ...    ...      ...        ...        ...
# 993     EMP1046   Anvi Bhavsar  150.0  unknown         IT       Pune
# 994         NaN         Charvi  150.0   110570        NaN     Mumbai
# 995     EMP1067            NaN   -5.0  unknown    Finance        NaN
# 997     EMP1099            NaN    NaN      NaN        NaN  Bangalore
# 999         NaN     Gokul Kota  150.0    50626    Finance       Pune
#
#                       Email  Phone_Number   Join_Date  Experience_Years  \
# ...

# %%
df[df['Employee_ID'] == 'EMP1099']
# Out:
#     Employee_ID   Name    Age  Salary Department       City          Email  \
# 247     EMP1099  Anahi  150.0     NaN         IT  Hyderabad            NaN
# 312     EMP1099    NaN    NaN   63204         HR    Chennai  invalid_email
# 902     EMP1099    NaN   56.0  118669    Support        NaN            NaN
# 997     EMP1099    NaN    NaN     NaN        NaN  Bangalore   pranay@gmail
#
#      Phone_Number   Join_Date  Experience_Years  Performance_Score  Gender
# 247  1.234500e+04         NaN               NaN                2.0    Male
# 312  1.000000e+15         NaN              10.5                2.0     NaN
# 902  1.234500e+04         NaN              10.3                1.0  Female
# 997  1.234500e+04  32-13-2023               7.7               10.0    Male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        671 non-null    object
#  1   Name               501 non-null    object
#  2   Age                765 non-null    float64
#  3   Salary             736 non-null    object
#  4   Department         857 non-null    object
#  5   City               857 non-null    object
#  6   Email              717 non-null    object
#  7   Phone_Number       757 non-null    float64
#  8   Join_Date          679 non-null    object
#  9   Experience_Years   647 non-null    float64
#  10  Performance_Score  652 non-null    float64
#  11  Gender             583 non-null    object
# dtypes: float64(4), object(8)
# memory usage: 93.9+ KB

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ## Data Cleaning

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Name', 'Age', 'Salary', 'Department', 'City', 'Email',
#        'Phone_Number', 'Join_Date', 'Experience_Years', 'Performance_Score',
#        'Gender'],
#       dtype='object')

# %%
df['Employee_ID'].head()
# Out:
# 0    EMP1000
# 1        NaN
# 2    EMP1002
# 3        NaN
# 4        NaN
# Name: Employee_ID, dtype: object

# %%
df['Employee_ID'] = df['Employee_ID'].str.strip().str.upper()

# %%
df.drop_duplicates(subset='Employee_ID', inplace=True)

# %%
df['Employee_ID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Employee_ID'].isnull().mean()
# Out:
# np.float64(0.002403846153846154)

# %%
df['Employee_ID'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['Employee_ID'].head(10)
# Out:
# 0     EMP1000
# 1         NaN
# 2     EMP1002
# 5     EMP1004
# 6     EMP1068
# 7     EMP1007
# 9     EMP1076
# 10    EMP1084
# 11    EMP1008
# 14    EMP1035
# Name: Employee_ID, dtype: object

# %%
df.dropna(subset='Employee_ID', inplace=True)

# %%
df['Employee_ID'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Name', 'Age', 'Salary', 'Department', 'City', 'Email',
#        'Phone_Number', 'Join_Date', 'Experience_Years', 'Performance_Score',
#        'Gender'],
#       dtype='object')

# %%
df['Age'].unique()
# Out:
# array([ nan,  -5.,  35., 150.,  19.,  57.,  47.,  54.,  32.,  43.,  53.,
#         44.,  38.,  24.,  42.,  21.,  34.,  27.,  41.,  59.,  28.,  56.,
#         39.,  48.,  60.,  20.,  46.,  26.,  25.,  45.,  37.,  55.,  50.,
#         18.,  40.,  31.,  58.,  52.,  22.,  29.,  36.,  51.,  23.])

# %%
df['Age'].dtypes
# Out:
# dtype('float64')

# %%
df['Age'] = df['Age'].astype('Int64')

# %%
df['Age'].dtypes
# Out:
# Int64Dtype()

# %%
df['Age'].unique()
# Out:
# <IntegerArray>
# [<NA>,   -5,   35,  150,   19,   57,   47,   54,   32,   43,   53,   44,   38,
#    24,   42,   21,   34,   27,   41,   59,   28,   56,   39,   48,   60,   20,
#    46,   26,   25,   45,   37,   55,   50,   18,   40,   31,   58,   52,   22,
#    29,   36,   51,   23]
# Length: 43, dtype: Int64

# %%
df.loc[df['Age']< 0,'Age'] = np.nan

# %%
df.loc[df['Age']>110,'Age'] = np.nan

# %%
df['Age'].unique()
# Out:
# <IntegerArray>
# [<NA>,   35,   19,   57,   47,   54,   32,   43,   53,   44,   38,   24,   42,
#    21,   34,   27,   41,   59,   28,   56,   39,   48,   60,   20,   46,   26,
#    25,   45,   37,   55,   50,   18,   40,   31,   58,   52,   22,   29,   36,
#    51,   23]
# Length: 41, dtype: Int64

# %% [markdown]
# #

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Name', 'Age', 'Salary', 'Department', 'City', 'Email',
#        'Phone_Number', 'Join_Date', 'Experience_Years', 'Performance_Score',
#        'Gender'],
#       dtype='object')

# %%
df['Salary'].dtypes.name
# Out:
# 'object'

# %%
df['Salary'] = pd.to_numeric(df['Salary'],errors='coerce')

# %%
df[df['Salary']< 0].size
# Out:
# 1332

# %%
df.loc[df['Salary']< 0,'Salary'] = np.nan

# %%
df['Salary'].isnull().mean()*100
# Out:
# np.float64(77.59036144578313)

# %% [markdown]
# #

# %%
df['Department'].unique()
# Out:
# array(['Support', nan, 'HR', 'IT', 'Finance', 'Marketing', 'Sales'],
#       dtype=object)

# %%
df['Department'] = df['Department'].str.title()

# %%
df['Department'] = df['Department'].fillna(df['Department'].mode()[0])

# %%
df['Department'].unique()
# Out:
# array(['Support', 'Hr', 'It', 'Finance', 'Marketing', 'Sales'],
#       dtype=object)

# %%
df['Department'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #

# %%
df['City'].unique()
# Out:
# array(['Bangalore', 'Chennai', 'Hyderabad', 'Delhi', 'Pune', 'Mumbai',
#        nan], dtype=object)

# %%
df['City'] = df['City'].str.strip().str.title()

# %%
df['City'] = df.groupby('Department')['City'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
df['City'].unique()
# Out:
# array(['Bangalore', 'Chennai', 'Hyderabad', 'Delhi', 'Pune', 'Mumbai'],
#       dtype=object)

# %%
df['City'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #

# %%
df['Email'].isnull().sum()
# Out:
# np.int64(114)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates(subset='Email', keep='first')

# %% [markdown]
# #

# %%
df['Experience_Years']
# Out:
# 0       0.4
# 2       NaN
# 7       NaN
# 9      11.0
# 11      NaN
#        ...
# 962    -3.0
# 976    -3.0
# 986    -3.0
# 989     NaN
# 998     3.7
# Name: Experience_Years, Length: 177, dtype: float64

# %%
df['Experience_Years'] = np.abs(df['Experience_Years'])
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_6836\3548653902.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Experience_Years'] = np.abs(df['Experience_Years'])

# %%
df['Experience_Years'].isnull().sum()
# Out:
# np.int64(64)

# %%
df['Experience_Years'] = (df.groupby(['Department', 'City'])['Experience_Years'].transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x.median())))

# %%
df['Experience_Years'].isnull().sum()
# Out:
# np.int64(3)

# %%
df['Experience_Years'] = df['Experience_Years'].fillna(df['Experience_Years'].mode()[0])

# %%
df['Experience_Years'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #

# %%
df['Phone_Number'].dtype
# Out:
# dtype('float64')

# %%
df['Phone_Number'].head(10)
# Out:
# 0              NaN
# 2     4.470941e+09
# 7     1.000000e+15
# 9     9.811370e+09
# 11    1.234500e+04
# 14    5.642615e+09
# 17    1.234500e+04
# 20    5.143210e+09
# 23             NaN
# 24    1.000000e+15
# Name: Phone_Number, dtype: float64

# %%
df['Phone_Number'].tail()
# Out:
# 962    1.000000e+15
# 976    1.234500e+04
# 986             NaN
# 989             NaN
# 998    1.000000e+15
# Name: Phone_Number, dtype: float64

# %%
df = df.drop(columns='Phone_Number')

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Name', 'Age', 'Salary', 'Department', 'City', 'Email',
#        'Join_Date', 'Experience_Years', 'Performance_Score', 'Gender'],
#       dtype='object')

# %% [markdown]
# #

# %%
df['Join_Date'].unique()
# Out:
# array(['2022-01-30', '32-13-2023', nan, '2021-08-26', '2019-07-19',
#        '2017-09-27', '2023-07-13', '2020-05-26', '2020-03-10',
#        '2024-07-30', '2026-04-01', '2018-11-17', '2024-08-21',
#        '2023-07-31', '2025-02-14', '2019-02-18', '2022-03-18',
#        '2016-06-20', '2021-03-19', '2020-08-03', '2022-06-17',
#        '2021-05-30', '2023-06-17', '2021-05-07', '2023-01-02',
#        '2023-03-12', '2023-08-21', '2022-02-08', '2020-08-29',
#        '2016-12-02', '2026-03-07', '2021-11-25', '2017-03-02',
#        '2025-03-03', '2022-07-25', '2020-01-12', '2023-10-17',
#        '2020-12-18', '2022-11-03', '2024-01-12', '2017-08-17',
#        '2020-09-04', '2018-05-02', '2024-09-26', '2023-08-03',
#        '2019-05-12', '2021-03-31', '2026-04-07', '2022-11-25',
#        '2017-08-15', '2021-12-26', '2020-06-07', '2021-09-27',
#        '2021-05-18', '2017-08-31', '2024-03-30', '2019-05-14'],
#       dtype=object)

# %%
df['Join_Date'].dtypes
# Out:
# dtype('O')

# %%
df['Join_Date'] = pd.to_datetime(df['Join_Date'],errors='coerce')

# %%
df['Join_Date'].dtypes.name
# Out:
# 'datetime64[ns]'

# %%
df['Join_Date'].isnull().sum()
# Out:
# np.int64(122)

# %%
df['Join_Date'].isnull().mean()*100
# Out:
# np.float64(68.92655367231639)

# %%
df['Join_Date'] = (df.groupby(['Department', 'City'])['Join_Date'].transform(lambda x: x.fillna(x.median())))
# Out:
# C:\Users\Omkar Yallurkar\anaconda3\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1241: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\Omkar Yallurkar\anaconda3\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1241: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\Omkar Yallurkar\anaconda3\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1241: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\Omkar Yallurkar\anaconda3\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1241: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\Omkar Yallurkar\anaconda3\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1241: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# ...

# %%
df['Performance_Score'].isnull().sum()
# Out:
# np.int64(65)

# %%
df[ 'Performance_Score'].unique()
# Out:
# array([10., nan,  4.,  5.,  1.,  2.,  3.])

# %%
df[ 'Performance_Score'] = df[ 'Performance_Score'].fillna(df[ 'Performance_Score'].mean())

# %%
df['Performance_Score'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #

# %%
df['Gender'].unique()
# Out:
# array([nan, 'Female', 'Other', 'Male'], dtype=object)

# %%
df['Gender'].isna().sum()
# Out:
# np.int64(75)

# %%
df['Gender'] = df.groupby(['Department','City'])['Gender'].transform(lambda a : )

# %%
df['Gender'] = (df.groupby(['Department', 'City'])['Gender'].transform(lambda x: x.fillna(
              x.mode().iloc[0] if not x.mode().empty else np.nan ) ) )
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_6836\1610265594.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender'] = (df.groupby(['Department', 'City'])['Gender'].transform(lambda x: x.fillna(

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Other', nan], dtype=object)

# %%
df['Gender'].isna().sum()
# Out:
# np.int64(5)

# %%
df = df.dropna(subset='Gender')

# %%
df['Gender'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 172 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        172 non-null    object
#  1   Name               87 non-null     object
#  2   Age                45 non-null     Int64
#  3   Salary             45 non-null     float64
#  4   Department         172 non-null    object
#  5   City               172 non-null    object
#  6   Email              171 non-null    object
#  7   Join_Date          154 non-null    datetime64[ns]
#  8   Experience_Years   172 non-null    float64
#  9   Performance_Score  172 non-null    float64
#  10  Gender             172 non-null    object
# dtypes: Int64(1), datetime64[ns](1), float64(3), object(6)
# memory usage: 16.3+ KB

# %%
df.isnull().sum()
# Out:
# Employee_ID            0
# Name                  85
# Age                  127
# Salary               127
# Department             0
# City                   0
# Email                  1
# Join_Date             18
# Experience_Years       0
# Performance_Score      0
# Gender                 0
# dtype: int64

# %%
df['Age'] = (df.groupby('Department')['Age'].transform(lambda x: x.fillna(x.median())))
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_6836\1293470227.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'] = (df.groupby('Department')['Age'].transform(lambda x: x.fillna(x.median())))

# %%
df['Salary'] = (df.groupby('Department')['Salary'].transform(lambda x: x.fillna(x.median())))
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_6836\475869433.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salary'] = (df.groupby('Department')['Salary'].transform(lambda x: x.fillna(x.median())))

# %%
df.isnull().sum()
# Out:
# Employee_ID           0
# Name                 85
# Age                   0
# Salary                0
# Department            0
# City                  0
# Email                 1
# Join_Date            18
# Experience_Years      0
# Performance_Score     0
# Gender                0
# dtype: int64

# %%
df['Join_Date'] = (df.groupby('Department')['Join_Date'].transform(lambda x: x.fillna(x.median() if x.notna().sum() > 0 else pd.NaT)))
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_6836\277461103.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Join_Date'] = (df.groupby('Department')['Join_Date'].transform(lambda x: x.fillna(x.median() if x.notna().sum() > 0 else pd.NaT)))

# %%
df.isnull().sum()
# Out:
# Employee_ID           0
# Name                 85
# Age                   0
# Salary                0
# Department            0
# City                  0
# Email                 1
# Join_Date             0
# Experience_Years      0
# Performance_Score     0
# Gender                0
# dtype: int64

# %%
df = df.dropna(subset='Email')

# %%
df.isnull().sum()
# Out:
# Employee_ID           0
# Name                 84
# Age                   0
# Salary                0
# Department            0
# City                  0
# Email                 0
# Join_Date             0
# Experience_Years      0
# Performance_Score     0
# Gender                0
# dtype: int64

# %% [markdown]
# #

# %% [markdown]
# #

# %%
df.shape
# Out:
# (171, 11)

# %%
data.shape
# Out:
# (1000, 12)

# %% [markdown]
# ##### The dataset was cleaned by handling missing values, invalid entries, duplicates, and datatype issues, but significant data loss occurred due to excessive missing and incorrect records, resulting in a final dataset shape of (171, 11).
