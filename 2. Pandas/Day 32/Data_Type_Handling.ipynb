# %% [markdown]
# # Data Type Handling

# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('datatype_handling.csv')

# %%
data.sample(10)
# Out:
#      employee_id  name      age salary  joining_date department is_active  \
# 268         1269  Sita       25  25000    15-02-2024      Sales       NaN
# 200         1201  Ravi       25    NaN    2023/03/20    Finance        no
# 265         1266  Amit       25    NaN           NaN         IT        no
# 278         1279  Neha       25  40000    2024-01-10      Sales     False
# 145         1146  John      NaN  25000           NaN      Sales        no
# 287         1288  Sita       25  55000  invalid_date         HR      True
# 293         1294  John  unknown  40000    2023/03/20    Finance       NaN
# 290         1291  Neha       25  50000    2024-01-10    Finance       NaN
# 183         1184  Ravi      NaN  55000           NaN         IT       NaN
# 80          1081  Sita       31  50000           NaN         HR       NaN
#
#     rating
# 268    4.2
# 200    NaN
# 265    NaN
# 278    3.5
# 145    3.5
# 287    NaN
# 293      5
# 290    3.5
# 183    4.2
# 80     4.8

# %%
df = data.copy()

# %% [markdown]
# #### 1. Check datatype of all columns

# %%
df.dtypes
# Out:
# employee_id      int64
# name            object
# age             object
# salary          object
# joining_date    object
# department      object
# is_active       object
# rating          object
# dtype: object

# %% [markdown]
# #### 2. Check datatype of salary column

# %%
df['salary'].dtype.name
# Out:
# 'object'

# %% [markdown]
# #### 3. Count how many object columns exist

# %%
print((df.dtypes == 'object').sum())
# Out:
# 7

# %% [markdown]
# #### 4. Select only numeric columns

# %%
df.select_dtypes(include='number')
# Out:
#      employee_id
# 0           1001
# 1           1002
# 2           1003
# 3           1004
# 4           1005
# ..           ...
# 295         1296
# 296         1297
# 297         1298
# 298         1299
# 299         1300
#
# [300 rows x 1 columns]

# %% [markdown]
# #### 5. Select only string/object columns

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['name', 'age', 'salary', 'joining_date', 'department', 'is_active',
#        'rating'],
#       dtype='object')

# %% [markdown]
# #### 6. Convert age to numeric

# %%
df['age'] = pd.to_numeric(df["age"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "unknown"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df['age'] = pd.to_numeric(df["age"])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\numeric.py:232, in to_numeric(arg, errors, downcast, dtype_backend)
#     230 coerce_numeric = errors not in ("ignore", "raise")
#     231 try:
# --> 232     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233         values,
#     234         set(),
#     235         coerce_numeric=coerce_numeric,
#     236         convert_to_masked_nullable=dtype_backend is not lib.no_default
# ...

# %%
df['age'] = pd.to_numeric(df["age"], errors='coerce')

# %%
df['age'].dtype.name
# Out:
# 'float64'

# %% [markdown]
# #### 7. Convert salary to numeric

# %%
df['salary'] = pd.to_numeric(df['salary'],errors='coerce')

# %%
df['salary'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### 8. Convert joining_date to datetime

# %%
df['joining_date'] = pd.to_datetime(df['joining_date'])
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_19660\313696224.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['joining_date'] = pd.to_datetime(df['joining_date'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df['joining_date'] = pd.to_datetime(df['joining_date'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# ...

# %%
df['joining_date'] = pd.to_datetime(df['joining_date'],errors='coerce')
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_19660\1160629233.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['joining_date'] = pd.to_datetime(df['joining_date'],errors='coerce')

# %%
df['joining_date'].head(10)
# Out:
# 0   2024-02-15
# 1          NaT
# 2          NaT
# 3   2024-02-15
# 4          NaT
# 5          NaT
# 6          NaT
# 7          NaT
# 8          NaT
# 9          NaT
# Name: joining_date, dtype: datetime64[ns]

# %% [markdown]
# #### 9. Check memory usage of dataframe

# %%
df.memory_usage(deep=True)
# Out:
# Index             132
# employee_id      2400
# name            15900
# age              2400
# salary           2400
# joining_date     2400
# department      15864
# is_active       14335
# rating          14468
# dtype: int64

# %% [markdown]
# #### 10. Convert department to category datatype

# %%
df['department'] = df['department'].astype('category')

# %%
df.dtypes
# Out:
# employee_id              int64
# name                    object
# age                    float64
# salary                 float64
# joining_date    datetime64[ns]
# department            category
# is_active               object
# rating                  object
# dtype: object

# %% [markdown]
# ####

# %% [markdown]
# #### 11. Convert invalid salary values to NaN

# %%
df['salary'] = pd.to_numeric(df['salary'], errors='coerce')

# %% [markdown]
# #### 12. Convert invalid dates to NaT

# %%
df['joining_date'] = pd.to_datetime(df['joining_date'],errors = 'coerce')

# %%
df.head()
# Out:
#    employee_id  name   age   salary joining_date department is_active rating
# 0         1001  John   NaN  25000.0   2024-02-15    Finance     False    3.5
# 1         1002  Sita   NaN  25000.0          NaT      Sales        no    3.5
# 2         1003  Neha  22.0      NaN          NaT    Finance      True      5
# 3         1004  Sita   NaN  50000.0   2024-02-15         IT        no    NaN
# 4         1005  Sita   NaN  50000.0          NaT      Sales       NaN    3.5

# %%
data.head()
# Out:
#    employee_id  name      age         salary  joining_date department  \
# 0         1001  John  unknown          25000    15-02-2024    Finance
# 1         1002  Sita  unknown          25000    2024-01-10      Sales
# 2         1003  Neha       22  not_available    2024-01-10    Finance
# 3         1004  Sita      NaN          50000    15-02-2024         IT
# 4         1005  Sita  unknown          50000  invalid_date      Sales
#
#   is_active rating
# 0     False    3.5
# 1        no    3.5
# 2      True      5
# 3        no    NaN
# 4       NaN    3.5

# %% [markdown]
# #### 13. Convert is_active into boolean datatype

# %%
df['is_active'] = df['is_active'].astype(bool)

# %%
df['is_active'].dtype
# Out:
# dtype('bool')

# %%
df['is_active'].head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: is_active, dtype: bool

# %%
df3 = data.copy()

# %%
df3.dtypes
# Out:
# employee_id      int64
# name            object
# age             object
# salary          object
# joining_date    object
# department      object
# is_active       object
# rating          object
# dtype: object

# %%
df3.head(10)
# Out:
#    employee_id  name      age         salary  joining_date department  \
# 0         1001  John  unknown          25000    15-02-2024    Finance
# 1         1002  Sita  unknown          25000    2024-01-10      Sales
# 2         1003  Neha       22  not_available    2024-01-10    Finance
# 3         1004  Sita      NaN          50000    15-02-2024         IT
# 4         1005  Sita  unknown          50000  invalid_date      Sales
# 5         1006  Ravi       28            NaN    2024-01-10    Finance
# 6         1007  Neha       31          50000    2024-01-10    Finance
# 7         1008  Neha       22          55000           NaN         IT
# 8         1009  Neha       31  not_available  invalid_date    Finance
# 9         1010  Sita  unknown          50000    2024-01-10    Finance
#
#   is_active rating
# 0     False    3.5
# 1        no    3.5
# 2      True      5
# 3        no    NaN
# 4       NaN    3.5
# 5      True    4.8
# 6       NaN    NaN
# 7     False    4.8
# ...

# %%
df3['is_active'] = df['is_active'].replace({'yes': 1,'no': 0})

# %%
df3.head(10)
# Out:
#    employee_id  name      age         salary  joining_date department  \
# 0         1001  John  unknown          25000    15-02-2024    Finance
# 1         1002  Sita  unknown          25000    2024-01-10      Sales
# 2         1003  Neha       22  not_available    2024-01-10    Finance
# 3         1004  Sita      NaN          50000    15-02-2024         IT
# 4         1005  Sita  unknown          50000  invalid_date      Sales
# 5         1006  Ravi       28            NaN    2024-01-10    Finance
# 6         1007  Neha       31          50000    2024-01-10    Finance
# 7         1008  Neha       22          55000           NaN         IT
# 8         1009  Neha       31  not_available  invalid_date    Finance
# 9         1010  Sita  unknown          50000    2024-01-10    Finance
#
#    is_active rating
# 0       True    3.5
# 1       True    3.5
# 2       True      5
# 3       True    NaN
# 4       True    3.5
# 5       True    4.8
# 6       True    NaN
# 7       True    4.8
# ...

# %%
df3.dtypes
# Out:
# employee_id      int64
# name            object
# age             object
# salary          object
# joining_date    object
# department      object
# is_active         bool
# rating          object
# dtype: object

# %%
df4 = data.copy()
df4.dtypes
# Out:
# employee_id      int64
# name            object
# age             object
# salary          object
# joining_date    object
# department      object
# is_active       object
# rating          object
# dtype: object

# %%
df4['is_active'] = df4['is_active'].map({ 'yes': 1,'no': 0, True: 1, False: 0})

# %%
df4.dtypes
# Out:
# employee_id       int64
# name             object
# age              object
# salary           object
# joining_date     object
# department       object
# is_active       float64
# rating           object
# dtype: object

# %%
df4['is_active'] = df4['is_active'].astype(bool)

# %%
df4.head()
# Out:
#    employee_id  name      age         salary  joining_date department  \
# 0         1001  John  unknown          25000    15-02-2024    Finance
# 1         1002  Sita  unknown          25000    2024-01-10      Sales
# 2         1003  Neha       22  not_available    2024-01-10    Finance
# 3         1004  Sita      NaN          50000    15-02-2024         IT
# 4         1005  Sita  unknown          50000  invalid_date      Sales
#
#    is_active rating
# 0       True    3.5
# 1      False    3.5
# 2       True      5
# 3      False    NaN
# 4       True    3.5

# %% [markdown]
# #### 14. Find columns with object datatype

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['name', 'rating'], dtype='object')

# %% [markdown]
# #### 15. Find columns with numeric datatype

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['employee_id', 'age', 'salary'], dtype='object')

# %% [markdown]
# #### 16. Automatically infer better datatypes

# %%
df2 = data.copy()

# %%
df2.dtypes
# Out:
# employee_id      int64
# name            object
# age             object
# salary          object
# joining_date    object
# department      object
# is_active       object
# rating          object
# dtype: object

# %%
df2 = df2.infer_objects()

# %%
df2.dtypes
# Out:
# employee_id      int64
# name            object
# age             object
# salary          object
# joining_date    object
# department      object
# is_active       object
# rating          object
# dtype: object

# %%
df2 = df2.convert_dtypes()

# %%
df2.dtypes
# Out:
# employee_id              Int64
# name            string[python]
# age             string[python]
# salary          string[python]
# joining_date    string[python]
# department      string[python]
# is_active       string[python]
# rating          string[python]
# dtype: object

# %% [markdown]
# #### 17. Use convert_dtypes() on full dataframe

# %%
df6 = data.copy()
df6.dtypes
# Out:
# employee_id      int64
# name            object
# age             object
# salary          object
# joining_date    object
# department      object
# is_active       object
# rating          object
# dtype: object

# %%
df6 = df6.convert_dtypes()
df6.dtypes
# Out:
# employee_id              Int64
# name            string[python]
# age             string[python]
# salary          string[python]
# joining_date    string[python]
# department      string[python]
# is_active       string[python]
# rating          string[python]
# dtype: object

# %% [markdown]
# #### 18.  Convert multiple columns together

# %%
df7 = data.copy()
df7.dtypes
# Out:
# employee_id      int64
# name            object
# age             object
# salary          object
# joining_date    object
# department      object
# is_active       object
# rating          object
# dtype: object

# %% [raw]
# df7 = df7.astype({'department': 'category', 'rating':'float'})
# ValueError: could not convert string to float: 'bad': Error while type casting for column 'rating'

# %%
df7.head()
# Out:
#    employee_id  name      age         salary  joining_date department  \
# 0         1001  John  unknown          25000    15-02-2024    Finance
# 1         1002  Sita  unknown          25000    2024-01-10      Sales
# 2         1003  Neha       22  not_available    2024-01-10    Finance
# 3         1004  Sita      NaN          50000    15-02-2024         IT
# 4         1005  Sita  unknown          50000  invalid_date      Sales
#
#   is_active rating
# 0     False    3.5
# 1        no    3.5
# 2      True      5
# 3        no    NaN
# 4       NaN    3.5

# %%
df7.tail()
# Out:
#      employee_id  name      age         salary joining_date department  \
# 295         1296  Sita       28          55000   2024-01-10         IT
# 296         1297  Sita  unknown          55000          NaN      Sales
# 297         1298  Neha       22          25000   2023/03/20         HR
# 298         1299  John      NaN  not_available   2023/03/20      Sales
# 299         1300  Amit       31          50000   2024-01-10    Finance
#
#     is_active rating
# 295       NaN    4.2
# 296     False    NaN
# 297     False    3.5
# 298       yes    3.5
# 299       NaN    3.5

# %%
df7.sample(10)
# Out:
#      employee_id  name      age         salary  joining_date department  \
# 192         1193  John       25          55000  invalid_date         HR
# 115         1116  Sita      NaN          25000    15-02-2024      Sales
# 91          1092  Amit       28          50000           NaN    Finance
# 65          1066  John       25          25000    2024-01-10    Finance
# 157         1158  Sita       31          25000  invalid_date    Finance
# 207         1208  Neha       22          40000    15-02-2024         HR
# 149         1150  John       31            NaN  invalid_date    Finance
# 140         1141  Amit      NaN  not_available    2023/03/20         IT
# 4           1005  Sita  unknown          50000  invalid_date      Sales
# 298         1299  John      NaN  not_available    2023/03/20      Sales
#
#     is_active rating
# 192       NaN    3.5
# 115      True      5
# 91      False    NaN
# 65         no    NaN
# 157       yes    NaN
# 207     False      5
# ...

# %%
df7['rating'].unique()
# Out:
# array(['3.5', '5', nan, '4.8', '4.2', 'bad'], dtype=object)

# %%
df7['rating'] = df7['rating'].replace('bad' , 1)

# %%
df7 = df7.astype({'department': 'category', 'rating':'float'})

# %%
df7.dtypes
# Out:
# employee_id        int64
# name              object
# age               object
# salary            object
# joining_date      object
# department      category
# is_active         object
# rating           float64
# dtype: object

# %% [markdown]
# #### 19. Extract year from joining_date

# %%
df8 = data.copy()

# %%
df8['joining_date'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 df8['joining_date'].dt.year
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
df8['joining_date'] = pd.to_datetime(df8['joining_date'],errors = 'coerce')
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_19660\1087840459.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df8['joining_date'] = pd.to_datetime(df8['joining_date'],errors = 'coerce')

# %%
df8['year'] = df8['joining_date'].dt.year

# %%
df8.head()
# Out:
#    employee_id  name      age         salary joining_date department  \
# 0         1001  John  unknown          25000   2024-02-15    Finance
# 1         1002  Sita  unknown          25000          NaT      Sales
# 2         1003  Neha       22  not_available          NaT    Finance
# 3         1004  Sita      NaN          50000   2024-02-15         IT
# 4         1005  Sita  unknown          50000          NaT      Sales
#
#   is_active rating    year
# 0     False    3.5  2024.0
# 1        no    3.5     NaN
# 2      True      5     NaN
# 3        no    NaN  2024.0
# 4       NaN    3.5     NaN

# %% [markdown]
# #### 20. Extract month from joining_date

# %%
df8['month'] = df8['joining_date'].dt.month

# %%
df8.head()
# Out:
#    employee_id  name      age         salary joining_date department  \
# 0         1001  John  unknown          25000   2024-02-15    Finance
# 1         1002  Sita  unknown          25000          NaT      Sales
# 2         1003  Neha       22  not_available          NaT    Finance
# 3         1004  Sita      NaN          50000   2024-02-15         IT
# 4         1005  Sita  unknown          50000          NaT      Sales
#
#   is_active rating    year  month
# 0     False    3.5  2024.0    2.0
# 1        no    3.5     NaN    NaN
# 2      True      5     NaN    NaN
# 3        no    NaN  2024.0    2.0
# 4       NaN    3.5     NaN    NaN

# %% [raw]
# df8= df8.astype({'year': int, 'month':int})
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer: Error while type casting for column 'year'

# %%
df8= df8.astype({'year':'Int64', 'month':'Int64'})

# %%
df8.head()
# Out:
#    employee_id  name      age         salary joining_date department  \
# 0         1001  John  unknown          25000   2024-02-15    Finance
# 1         1002  Sita  unknown          25000          NaT      Sales
# 2         1003  Neha       22  not_available          NaT    Finance
# 3         1004  Sita      NaN          50000   2024-02-15         IT
# 4         1005  Sita  unknown          50000          NaT      Sales
#
#   is_active rating  year  month
# 0     False    3.5  2024      2
# 1        no    3.5  <NA>   <NA>
# 2      True      5  <NA>   <NA>
# 3        no    NaN  2024      2
# 4       NaN    3.5  <NA>   <NA>

# %% [markdown]
# #### 21. Find non-numeric values in salary

# %%
df8[pd.to_numeric(df8['salary'], errors='coerce').isnull()]
# coerce :   Invalid → NaN
# Out:
#      employee_id  name      age         salary joining_date department  \
# 2           1003  Neha       22  not_available          NaT    Finance
# 5           1006  Ravi       28            NaN          NaT    Finance
# 8           1009  Neha       31  not_available          NaT    Finance
# 10          1011  John  unknown            NaN          NaT         IT
# 15          1016  Ravi       25            NaN   2024-02-15         HR
# ..           ...   ...      ...            ...          ...        ...
# 284         1285  Amit  unknown            NaN   2024-02-15      Sales
# 288         1289  Neha       28            NaN   2024-02-15         IT
# 291         1292  Amit  unknown  not_available          NaT      Sales
# 294         1295  John      NaN            NaN          NaT         HR
# 298         1299  John      NaN  not_available          NaT      Sales
#
#     is_active rating  year  month
# 2        True      5  <NA>   <NA>
# 5        True    4.8  <NA>   <NA>
# ...

# %% [markdown]
# #### 22. Replace invalid rating values with NaN

# %%
df8['rating'] = pd.to_numeric(df8['rating'], errors='coerce')

# %%
df8.head()
# Out:
#    employee_id  name      age         salary joining_date department  \
# 0         1001  John  unknown          25000   2024-02-15    Finance
# 1         1002  Sita  unknown          25000          NaT      Sales
# 2         1003  Neha       22  not_available          NaT    Finance
# 3         1004  Sita      NaN          50000   2024-02-15         IT
# 4         1005  Sita  unknown          50000          NaT      Sales
#
#   is_active  rating  year  month
# 0     False     3.5  2024      2
# 1        no     3.5  <NA>   <NA>
# 2      True     5.0  <NA>   <NA>
# 3        no     NaN  2024      2
# 4       NaN     3.5  <NA>   <NA>

# %% [markdown]
# #### 23. Convert age to nullable integer (Int64)

# %%
df8['age'] = pd.to_numeric(df8['age'], errors='coerce').astype('Int64')

# %%
df8.dtypes
# Out:
# employee_id              int64
# name                    object
# age                      Int64
# salary                  object
# joining_date    datetime64[ns]
# department              object
# is_active               object
# rating                 float64
# year                     Int64
# month                    Int64
# dtype: object

# %% [markdown]
# #### 24. Detect datetime columns programmatically

# %%
df9 = data.copy()
for col in df9.columns:
    if is_datetime64_any_dtype(df[col]):
        print(col)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[133], line 3
#       1 df9 = data.copy()
#       2 for col in df9.columns:
# ----> 3     if is_datetime64_any_dtype(df[col]):
#       4         print(col)
#
# NameError: name 'is_datetime64_any_dtype' is not defined

# %%
from pandas.api.types import is_datetime64_any_dtype
for col in df9.columns:
    if is_datetime64_any_dtype(df9[col]):
        print(col)

# %%
df.dtypes
# Out:
# employee_id              int64
# name                    object
# age                    float64
# salary                 float64
# joining_date    datetime64[ns]
# department            category
# is_active                 bool
# rating                  object
# dtype: object

# %%
for col in df.columns:
    if is_datetime64_any_dtype(df[col]):
        print(col)
# Out:
# joining_date

# %% [markdown]
# #### 25. Detect numeric columns programmatically

# %%
from pandas.api.types import is_numeric_dtype

for col in df9.columns:
    if is_numeric_dtype(df9[col]):
        print(col)
# Out:
# employee_id

# %%
df9.dtypes
# Out:
# employee_id      int64
# name            object
# age             object
# salary          object
# joining_date    object
# department      object
# is_active       object
# rating          object
# dtype: object

# %%
num_cols = ['age','salary','rating']
for col in num_cols:
    df9[col] = pd.to_numeric(df9[col],errors='coerce')

# %%
df9.dtypes
# Out:
# employee_id       int64
# name             object
# age             float64
# salary          float64
# joining_date     object
# department       object
# is_active        object
# rating          float64
# dtype: object

# %%
for col in df9.columns:
    if is_numeric_dtype(df9[col]):
        print(col)
# Out:
# employee_id
# age
# salary
# rating

# %% [markdown]
# #### 26.  Detect string columns programmatically

# %%
from pandas.api.types import is_string_dtype

for col in df9.columns:
    if is_string_dtype(df9[col]):
        print(col)
# Out:
# name
# department

# %% [markdown]
# #### 27. Convert all object columns to category

# %%
for col in df9.select_dtypes(include='object'):
    df9[col] = df9[col].astype('category')

# %%
df9.dtypes
# Out:
# employee_id        int64
# name            category
# age              float64
# salary           float64
# joining_date    category
# department      category
# is_active       category
# rating           float64
# dtype: object

# %% [markdown]
# #### 28. Convert all possible columns to optimized datatypes

# %%
df10 = data.copy()

# %%
df10 = df10.convert_dtypes()

# %%
df10.dtypes
# Out:
# employee_id              Int64
# name            string[python]
# age             string[python]
# salary          string[python]
# joining_date    string[python]
# department      string[python]
# is_active       string[python]
# rating          string[python]
# dtype: object

# %% [markdown]
# #### 29. Create datatype summary table

# %%
df10.dtypes.reset_index(name='datatype')
# Out:
#           index        datatype
# 0   employee_id           Int64
# 1          name  string[python]
# 2           age  string[python]
# 3        salary  string[python]
# 4  joining_date  string[python]
# 5    department  string[python]
# 6     is_active  string[python]
# 7        rating  string[python]

# %% [markdown]
# #### 30. Find rows where date conversion failed

# %%
df11 = data.copy()
temp = pd.to_datetime(df11['joining_date'], errors='coerce')

df11[temp.isnull()]
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_19660\1876374928.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   temp = pd.to_datetime(df11['joining_date'], errors='coerce')
#      employee_id  name      age         salary  joining_date department  \
# 1           1002  Sita  unknown          25000    2024-01-10      Sales
# 2           1003  Neha       22  not_available    2024-01-10    Finance
# 4           1005  Sita  unknown          50000  invalid_date      Sales
# 5           1006  Ravi       28            NaN    2024-01-10    Finance
# 6           1007  Neha       31          50000    2024-01-10    Finance
# ..           ...   ...      ...            ...           ...        ...
# 295         1296  Sita       28          55000    2024-01-10         IT
# 296         1297  Sita  unknown          55000           NaN      Sales
# ...
