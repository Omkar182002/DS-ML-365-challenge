# %% [markdown]
# #### Windows Function

# %% [markdown]
# # Exponential Weighted Moving

# %%
import pandas as pd

sales_df = pd.DataFrame({
    'Sales': [
        100, 120, 150, 170, 200,
        220, 250, 270, 300, 320,
        310, 330, 360, 390, 410,
        430, 450, 470, 490, 520,
        540, 560, 580, 600, 620,
        640, 660, 680, 700, 720
    ]
})

print(sales_df)
# Out:
#     Sales
# 0     100
# 1     120
# 2     150
# 3     170
# 4     200
# 5     220
# 6     250
# 7     270
# 8     300
# 9     320
# 10    310
# 11    330
# 12    360
# 13    390
# 14    410
# 15    430
# 16    450
# 17    470
# 18    490
# 19    520
# 20    540
# 21    560
# 22    580
# 23    600
# 24    620
# 25    640
# 26    660
# 27    680
# 28    700
# 29    720

# %% [markdown]
# ## 1 — Large Sales Dataset

# %% [markdown]
# ### 1. Create EWM mean using span=3.
# Recent values get higher importance.

# %%
sales_df['EWM_Mean_Span3'] = sales_df['Sales'].ewm(span=3).mean()

# %% [markdown]
# ### 2. Create EWM mean using span=5.

# %%
sales_df['EWM_Mean_Span5'] = sales_df['Sales'].ewm(span=5).mean()
# Smoother trend because larger span gives less weight to sudden changes.

# %% [markdown]
# ### 3. Compare EWM mean vs rolling mean.

# %%
sales_df['Rolling_Mean_3'] = sales_df['Sales'].rolling(window=3).mean()

sales_df['EWM_Mean_3'] = sales_df['Sales'].ewm(span=3).mean()

print(sales_df[['Sales', 'Rolling_Mean_3', 'EWM_Mean_3']])
# Out:
#     Sales  Rolling_Mean_3  EWM_Mean_3
# 0     100             NaN  100.000000
# 1     120             NaN  113.333333
# 2     150      123.333333  134.285714
# 3     170      146.666667  153.333333
# 4     200      173.333333  177.419355
# 5     220      196.666667  199.047619
# 6     250      223.333333  224.724409
# 7     270      246.666667  247.450980
# 8     300      273.333333  273.776908
# 9     320      296.666667  296.911046
# 10    310      310.000000  303.458720
# 11    330      320.000000  316.732601
# 12    360      333.333333  338.368942
# 13    390      360.000000  364.186047
# 14    410      386.666667  387.093722
# 15    430      410.000000  408.547189
# 16    450      430.000000  429.273752
# 17    470      450.000000  449.636954
# 18    490      470.000000  469.818515
# 19    520      493.333333  494.909282
# 20    540      516.666667  517.454652
# 21    560      540.000000  538.727331
# 22    580      560.000000  559.363668
# 23    600      580.000000  579.681835
# 24    620      600.000000  599.840918
# 25    640      620.000000  619.920459
# 26    660      640.000000  639.960230
# 27    680      660.000000  659.980115
# 28    700      680.000000  679.990058
# 29    720      700.000000  699.995029

# %% [markdown]
# ### 4. Compare EWM mean vs expanding mean.

# %%
sales_df['Expanding_Mean'] = sales_df['Sales'].expanding().mean()

sales_df['EWM_Mean'] = sales_df['Sales'].ewm(span=5).mean()

print(sales_df[['Sales', 'Expanding_Mean', 'EWM_Mean']])
# Out:
#     Sales  Expanding_Mean    EWM_Mean
# 0     100      100.000000  100.000000
# 1     120      110.000000  112.000000
# 2     150      123.333333  130.000000
# 3     170      135.000000  146.615385
# 4     200      148.000000  167.109005
# 5     220      160.000000  186.436090
# 6     250      172.857143  208.941234
# 7     270      185.000000  230.120539
# 8     300      197.777778  254.035783
# 9     320      210.000000  276.411891
# 10    310      219.090909  287.738879
# 11    330      228.333333  301.935336
# 12    360      238.461538  321.390188
# 13    390      249.285714  344.338735
# 14    410      260.000000  366.275920
# 15    430      270.625000  387.549668
# 16    450      281.176471  408.387595
# 17    470      291.666667  428.938969
# 18    490      302.105263  449.301832
# 19    520      313.000000  472.874977
# 20    540      323.809524  495.254471
# 21    560      334.545455  516.839199
# 22    580      345.217391  537.894676
# 23    600      355.833333  558.597680
# 24    620      366.400000  579.065931
# 25    640      376.923077  599.377823
# 26    660      387.407407  619.585571
# 27    680      397.857143  639.723950
# 28    700      408.275862  659.816124
# 29    720      418.666667  679.877521

# %% [markdown]
# ### 5. Detect recent sales trend.

# %%
sales_df['Recent_Trend'] = sales_df['Sales'].ewm(span=3).mean()

print(sales_df[['Sales', 'Recent_Trend']])
# Out:
#     Sales  Recent_Trend
# 0     100    100.000000
# 1     120    113.333333
# 2     150    134.285714
# 3     170    153.333333
# 4     200    177.419355
# 5     220    199.047619
# 6     250    224.724409
# 7     270    247.450980
# 8     300    273.776908
# 9     320    296.911046
# 10    310    303.458720
# 11    330    316.732601
# 12    360    338.368942
# 13    390    364.186047
# 14    410    387.093722
# 15    430    408.547189
# 16    450    429.273752
# 17    470    449.636954
# 18    490    469.818515
# 19    520    494.909282
# 20    540    517.454652
# 21    560    538.727331
# 22    580    559.363668
# 23    600    579.681835
# 24    620    599.840918
# 25    640    619.920459
# 26    660    639.960230
# 27    680    659.980115
# 28    700    679.990058
# 29    720    699.995029

# %% [markdown]
# ### 6. Detect sales acceleration periods.

# %%
sales_df['EWM_Trend'] = sales_df['Sales'].ewm(span=3).mean()

sales_df['Acceleration'] = sales_df['EWM_Trend'].diff()

print(sales_df[['Sales', 'EWM_Trend', 'Acceleration']])
# Out:
#     Sales   EWM_Trend  Acceleration
# 0     100  100.000000           NaN
# 1     120  113.333333     13.333333
# 2     150  134.285714     20.952381
# 3     170  153.333333     19.047619
# 4     200  177.419355     24.086022
# 5     220  199.047619     21.628264
# 6     250  224.724409     25.676790
# 7     270  247.450980     22.726571
# 8     300  273.776908     26.325928
# 9     320  296.911046     23.134138
# 10    310  303.458720      6.547674
# 11    330  316.732601     13.273881
# 12    360  338.368942     21.636341
# 13    390  364.186047     25.817105
# 14    410  387.093722     22.907676
# 15    430  408.547189     21.453466
# 16    450  429.273752     20.726564
# 17    470  449.636954     20.363201
# 18    490  469.818515     20.181562
# 19    520  494.909282     25.090766
# 20    540  517.454652     22.545370
# 21    560  538.727331     21.272679
# 22    580  559.363668     20.636337
# 23    600  579.681835     20.318167
# 24    620  599.840918     20.159083
# 25    640  619.920459     20.079541
# 26    660  639.960230     20.039770
# 27    680  659.980115     20.019885
# 28    700  679.990058     20.009943
# 29    720  699.995029     20.004971

# %% [markdown]
# ### 7. Detect sales slowdown periods.

# %%
sales_df['Slowdown'] = sales_df['Acceleration'] < 5

print(sales_df[['Sales', 'Acceleration', 'Slowdown']])
# Out:
#     Sales  Acceleration  Slowdown
# 0     100           NaN     False
# 1     120     13.333333     False
# 2     150     20.952381     False
# 3     170     19.047619     False
# 4     200     24.086022     False
# 5     220     21.628264     False
# 6     250     25.676790     False
# 7     270     22.726571     False
# 8     300     26.325928     False
# 9     320     23.134138     False
# 10    310      6.547674     False
# 11    330     13.273881     False
# 12    360     21.636341     False
# 13    390     25.817105     False
# 14    410     22.907676     False
# 15    430     21.453466     False
# 16    450     20.726564     False
# 17    470     20.363201     False
# 18    490     20.181562     False
# 19    520     25.090766     False
# 20    540     22.545370     False
# 21    560     21.272679     False
# 22    580     20.636337     False
# 23    600     20.318167     False
# 24    620     20.159083     False
# 25    640     20.079541     False
# 26    660     20.039770     False
# 27    680     20.019885     False
# 28    700     20.009943     False
# 29    720     20.004971     False

# %% [markdown]
# ### 8. Create EWM std.

# %%
sales_df['EWM_STD'] = sales_df['Sales'].ewm(span=5).std()

print(sales_df)
# Out:
#     Sales  EWM_Mean_Span3  EWM_Mean_Span5  Rolling_Mean_3  EWM_Mean_3  \
# 0     100      100.000000      100.000000             NaN  100.000000
# 1     120      113.333333      112.000000             NaN  113.333333
# 2     150      134.285714      130.000000      123.333333  134.285714
# 3     170      153.333333      146.615385      146.666667  153.333333
# 4     200      177.419355      167.109005      173.333333  177.419355
# 5     220      199.047619      186.436090      196.666667  199.047619
# 6     250      224.724409      208.941234      223.333333  224.724409
# 7     270      247.450980      230.120539      246.666667  247.450980
# 8     300      273.776908      254.035783      273.333333  273.776908
# 9     320      296.911046      276.411891      296.666667  296.911046
# 10    310      303.458720      287.738879      310.000000  303.458720
# 11    330      316.732601      301.935336      320.000000  316.732601
# 12    360      338.368942      321.390188      333.333333  338.368942
# 13    390      364.186047      344.338735      360.000000  364.186047
# 14    410      387.093722      366.275920      386.666667  387.093722
# 15    430      408.547189      387.549668      410.000000  408.547189
# 16    450      429.273752      408.387595      430.000000  429.273752
# 17    470      449.636954      428.938969      450.000000  449.636954
# 18    490      469.818515      449.301832      470.000000  469.818515
# 19    520      494.909282      472.874977      493.333333  494.909282
# 20    540      517.454652      495.254471      516.666667  517.454652
# 21    560      538.727331      516.839199      540.000000  538.727331
# 22    580      559.363668      537.894676      560.000000  559.363668
# 23    600      579.681835      558.597680      580.000000  579.681835
# 24    620      599.840918      579.065931      600.000000  599.840918
# 25    640      619.920459      599.377823      620.000000  619.920459
# 26    660      639.960230      619.585571      640.000000  639.960230
# 27    680      659.980115      639.723950      660.000000  659.980115
# 28    700      679.990058      659.816124      680.000000  679.990058
# 29    720      699.995029      679.877521      700.000000  699.995029
#
#     Expanding_Mean    EWM_Mean  Recent_Trend   EWM_Trend  Acceleration  \
# 0       100.000000  100.000000    100.000000  100.000000           NaN
# 1       110.000000  112.000000    113.333333  113.333333     13.333333
# 2       123.333333  130.000000    134.285714  134.285714     20.952381
# 3       135.000000  146.615385    153.333333  153.333333     19.047619
# 4       148.000000  167.109005    177.419355  177.419355     24.086022
# 5       160.000000  186.436090    199.047619  199.047619     21.628264
# 6       172.857143  208.941234    224.724409  224.724409     25.676790
# 7       185.000000  230.120539    247.450980  247.450980     22.726571
# 8       197.777778  254.035783    273.776908  273.776908     26.325928
# 9       210.000000  276.411891    296.911046  296.911046     23.134138
# 10      219.090909  287.738879    303.458720  303.458720      6.547674
# 11      228.333333  301.935336    316.732601  316.732601     13.273881
# 12      238.461538  321.390188    338.368942  338.368942     21.636341
# 13      249.285714  344.338735    364.186047  364.186047     25.817105
# 14      260.000000  366.275920    387.093722  387.093722     22.907676
# 15      270.625000  387.549668    408.547189  408.547189     21.453466
# 16      281.176471  408.387595    429.273752  429.273752     20.726564
# 17      291.666667  428.938969    449.636954  449.636954     20.363201
# 18      302.105263  449.301832    469.818515  469.818515     20.181562
# 19      313.000000  472.874977    494.909282  494.909282     25.090766
# 20      323.809524  495.254471    517.454652  517.454652     22.545370
# 21      334.545455  516.839199    538.727331  538.727331     21.272679
# 22      345.217391  537.894676    559.363668  559.363668     20.636337
# 23      355.833333  558.597680    579.681835  579.681835     20.318167
# 24      366.400000  579.065931    599.840918  599.840918     20.159083
# 25      376.923077  599.377823    619.920459  619.920459     20.079541
# 26      387.407407  619.585571    639.960230  639.960230     20.039770
# 27      397.857143  639.723950    659.980115  659.980115     20.019885
# 28      408.275862  659.816124    679.990058  679.990058     20.009943
# 29      418.666667  679.877521    699.995029  699.995029     20.004971
#
#     Slowdown    EWM_STD
# 0      False        NaN
# 1      False  14.142136
# 2      False  25.495098
# 3      False  29.932448
# 4      False  37.887865
# 5      False  41.668725
# 6      False  47.894856
# 7      False  50.590468
# 8      False  55.355919
# 9      False  56.970092
# 10     False  49.615307
# 11     False  46.168028
# 12     False  48.547284
# 13     False  53.658624
# 14     False  55.826092
# 15     False  56.613004
# 16     False  56.740685
# 17     False  56.572339
# 18     False  56.294273
# 19     False  59.169546
# 20     False  59.879260
# 21     False  59.621359
# 22     False  58.973552
# 23     False  58.223325
# 24     False  57.508564
# 25     False  56.887476
# 26     False  56.376350
# 27     False  55.970681
# 28     False  55.656954
# 29     False  55.419011

# %% [markdown]
# ### 9. Detect unstable sales periods.

# %%
sales_df['Unstable'] = sales_df['EWM_STD'] > 25

print(sales_df[['Sales', 'EWM_STD', 'Unstable']])
# Out:
#     Sales    EWM_STD  Unstable
# 0     100        NaN     False
# 1     120  14.142136     False
# 2     150  25.495098      True
# 3     170  29.932448      True
# 4     200  37.887865      True
# 5     220  41.668725      True
# 6     250  47.894856      True
# 7     270  50.590468      True
# 8     300  55.355919      True
# 9     320  56.970092      True
# 10    310  49.615307      True
# 11    330  46.168028      True
# 12    360  48.547284      True
# 13    390  53.658624      True
# 14    410  55.826092      True
# 15    430  56.613004      True
# 16    450  56.740685      True
# 17    470  56.572339      True
# 18    490  56.294273      True
# 19    520  59.169546      True
# 20    540  59.879260      True
# 21    560  59.621359      True
# 22    580  58.973552      True
# 23    600  58.223325      True
# 24    620  57.508564      True
# 25    640  56.887476      True
# 26    660  56.376350      True
# 27    680  55.970681      True
# 28    700  55.656954      True
# 29    720  55.419011      True

# %% [markdown]
# ### 10. Detect stable sales periods.

# %%
sales_df['Stable'] = sales_df['EWM_STD'] < 20

print(sales_df[['Sales', 'EWM_STD', 'Stable']])
# Out:
#     Sales    EWM_STD  Stable
# 0     100        NaN   False
# 1     120  14.142136    True
# 2     150  25.495098   False
# 3     170  29.932448   False
# 4     200  37.887865   False
# 5     220  41.668725   False
# 6     250  47.894856   False
# 7     270  50.590468   False
# 8     300  55.355919   False
# 9     320  56.970092   False
# 10    310  49.615307   False
# 11    330  46.168028   False
# 12    360  48.547284   False
# 13    390  53.658624   False
# 14    410  55.826092   False
# 15    430  56.613004   False
# 16    450  56.740685   False
# 17    470  56.572339   False
# 18    490  56.294273   False
# 19    520  59.169546   False
# 20    540  59.879260   False
# 21    560  59.621359   False
# 22    580  58.973552   False
# 23    600  58.223325   False
# 24    620  57.508564   False
# 25    640  56.887476   False
# 26    660  56.376350   False
# 27    680  55.970681   False
# 28    700  55.656954   False
# 29    720  55.419011   False

# %% [markdown]
# ### 11. Use adjust=True.

# %%
sales_df['Adjust_True'] = sales_df['Sales'].ewm(
    span=5,
    adjust=True
).mean()

print(sales_df[['Sales', 'Adjust_True']])
# Out:
#     Sales  Adjust_True
# 0     100   100.000000
# 1     120   112.000000
# 2     150   130.000000
# 3     170   146.615385
# 4     200   167.109005
# 5     220   186.436090
# 6     250   208.941234
# 7     270   230.120539
# 8     300   254.035783
# 9     320   276.411891
# 10    310   287.738879
# 11    330   301.935336
# 12    360   321.390188
# 13    390   344.338735
# 14    410   366.275920
# 15    430   387.549668
# 16    450   408.387595
# 17    470   428.938969
# 18    490   449.301832
# 19    520   472.874977
# 20    540   495.254471
# 21    560   516.839199
# 22    580   537.894676
# 23    600   558.597680
# 24    620   579.065931
# 25    640   599.377823
# 26    660   619.585571
# 27    680   639.723950
# 28    700   659.816124
# 29    720   679.877521

# %% [markdown]
# ### 12. Use adjust=False.

# %%
sales_df['Adjust_False'] = sales_df['Sales'].ewm(
    span=5,
    adjust=False
).mean()

print(sales_df[['Sales', 'Adjust_False']])
# Out:
#     Sales  Adjust_False
# 0     100    100.000000
# 1     120    106.666667
# 2     150    121.111111
# 3     170    137.407407
# 4     200    158.271605
# 5     220    178.847737
# 6     250    202.565158
# 7     270    225.043439
# 8     300    250.028959
# 9     320    273.352639
# 10    310    285.568426
# 11    330    300.378951
# 12    360    320.252634
# 13    390    343.501756
# 14    410    365.667837
# 15    430    387.111892
# 16    450    408.074594
# 17    470    428.716396
# 18    490    449.144264
# 19    520    472.762843
# 20    540    495.175229
# 21    560    516.783486
# 22    580    537.855657
# 23    600    558.570438
# 24    620    579.046959
# 25    640    599.364639
# 26    660    619.576426
# 27    680    639.717617
# 28    700    659.811745
# 29    720    679.874497

# %% [markdown]
# ## 2 — Large Stock Market Dataset

# %%
stock_df = pd.DataFrame({
    'Price': [
        100, 102, 101, 105, 108,
        110, 115, 112, 118, 120,
        122, 125, 123, 128, 130,
        135, 138, 140, 145, 148,
        150, 152, 149, 155, 158,
        160, 162, 165, 168, 170
    ]
})

print(stock_df)
# Out:
#     Price
# 0     100
# 1     102
# 2     101
# 3     105
# 4     108
# 5     110
# 6     115
# 7     112
# 8     118
# 9     120
# 10    122
# 11    125
# 12    123
# 13    128
# 14    130
# 15    135
# 16    138
# 17    140
# 18    145
# 19    148
# 20    150
# 21    152
# 22    149
# 23    155
# 24    158
# 25    160
# 26    162
# 27    165
# 28    168
# 29    170

# %% [markdown]
# ### 1. Create EWM moving average.

# %%
stock_df['EWM_Mean'] = stock_df['Price'].ewm(span=5).mean()

print(stock_df)
# Out:
#     Price    EWM_Mean
# 0     100  100.000000
# 1     102  101.200000
# 2     101  101.105263
# 3     105  102.723077
# 4     108  104.748815
# 5     110  106.667669
# 6     115  109.617776
# 7     112  110.444092
# 8     118  113.029993
# 9     120  115.394330
# 10    122  117.621974
# 11    125  120.100418
# 12    123  121.071937
# 13    128  123.389229
# 14    130  125.597863
# 15    135  128.736688
# 16    138  131.827596
# 17    140  134.553575
# 18    145  138.037288
# 19    148  141.359191
# 20    150  144.240038
# 21    152  146.827038
# 22    149  147.551423
# 23    155  150.034430
# 24    158  152.689725
# 25    160  155.126548
# 26    162  157.417739
# 27    165  159.945189
# 28    168  162.630147
# 29    170  165.086777

# %% [markdown]
# ### 2. Create EWM volatility.

# %%
stock_df['EWM_Volatility'] = stock_df['Price'].ewm(span=5).std()

print(stock_df)
# Out:
#     Price    EWM_Mean  EWM_Volatility
# 0     100  100.000000             NaN
# 1     102  101.200000        1.414214
# 2     101  101.105263        0.903211
# 3     105  102.723077        2.383309
# 4     108  104.748815        3.496965
# 5     110  106.667669        3.991390
# 6     115  109.617776        5.531194
# 7     112  110.444092        4.626282
# 8     118  113.029993        5.501002
# 9     120  115.394330        5.799784
# 10    122  117.621974        5.872792
# 11    125  120.100418        6.172278
# 12    123  121.071937        5.258029
# 13    128  123.389229        5.635803
# 14    130  125.597863        5.771115
# 15    135  128.736688        6.838968
# 16    138  131.827596        7.417362
# 17    140  134.553575        7.431310
# 18    145  138.037288        8.193335
# 19    148  141.359191        8.504295
# 20    150  144.240038        8.303743
# 21    152  146.827038        7.917870
# 22    149  147.551423        6.565367
# 23    155  150.034430        6.644331
# 24    158  152.689725        6.859762
# 25    160  155.126548        6.798172
# 26    162  157.417739        6.628223
# 27    165  159.945189        6.727441
# 28    168  162.630147        6.942225
# 29    170  165.086777        6.871466

# %% [markdown]
# ### 3. Detect high volatility periods.

# %%
stock_df['High_Volatility'] = (
    stock_df['EWM_Volatility'] > 4
)

print(
    stock_df[
        ['Price', 'EWM_Volatility', 'High_Volatility']
    ]
)
# Out:
#     Price  EWM_Volatility  High_Volatility
# 0     100             NaN            False
# 1     102        1.414214            False
# 2     101        0.903211            False
# 3     105        2.383309            False
# 4     108        3.496965            False
# 5     110        3.991390            False
# 6     115        5.531194             True
# 7     112        4.626282             True
# 8     118        5.501002             True
# 9     120        5.799784             True
# 10    122        5.872792             True
# 11    125        6.172278             True
# 12    123        5.258029             True
# 13    128        5.635803             True
# 14    130        5.771115             True
# 15    135        6.838968             True
# 16    138        7.417362             True
# 17    140        7.431310             True
# 18    145        8.193335             True
# 19    148        8.504295             True
# 20    150        8.303743             True
# 21    152        7.917870             True
# 22    149        6.565367             True
# 23    155        6.644331             True
# 24    158        6.859762             True
# 25    160        6.798172             True
# 26    162        6.628223             True
# 27    165        6.727441             True
# 28    168        6.942225             True
# 29    170        6.871466             True

# %% [markdown]
# ### 4. Detect high volatility periods.

# %%
stock_df['Low_Volatility'] = (
    stock_df['EWM_Volatility'] < 3
)

print(
    stock_df[
        ['Price', 'EWM_Volatility', 'Low_Volatility']
    ]
)
# Out:
#     Price  EWM_Volatility  Low_Volatility
# 0     100             NaN           False
# 1     102        1.414214            True
# 2     101        0.903211            True
# 3     105        2.383309            True
# 4     108        3.496965           False
# 5     110        3.991390           False
# 6     115        5.531194           False
# 7     112        4.626282           False
# 8     118        5.501002           False
# 9     120        5.799784           False
# 10    122        5.872792           False
# 11    125        6.172278           False
# 12    123        5.258029           False
# 13    128        5.635803           False
# 14    130        5.771115           False
# 15    135        6.838968           False
# 16    138        7.417362           False
# 17    140        7.431310           False
# 18    145        8.193335           False
# 19    148        8.504295           False
# 20    150        8.303743           False
# 21    152        7.917870           False
# 22    149        6.565367           False
# 23    155        6.644331           False
# 24    158        6.859762           False
# 25    160        6.798172           False
# 26    162        6.628223           False
# 27    165        6.727441           False
# 28    168        6.942225           False
# 29    170        6.871466           False

# %% [markdown]
# ### 5. Detect risky market periods.

# %%
stock_df['Risky_Market'] = (
    stock_df['EWM_Volatility'] > 5
)

print(
    stock_df[
        ['Price', 'EWM_Volatility', 'Risky_Market']
    ]
)
# Out:
#     Price  EWM_Volatility  Risky_Market
# 0     100             NaN         False
# 1     102        1.414214         False
# 2     101        0.903211         False
# 3     105        2.383309         False
# 4     108        3.496965         False
# 5     110        3.991390         False
# 6     115        5.531194          True
# 7     112        4.626282         False
# 8     118        5.501002          True
# 9     120        5.799784          True
# 10    122        5.872792          True
# 11    125        6.172278          True
# 12    123        5.258029          True
# 13    128        5.635803          True
# 14    130        5.771115          True
# 15    135        6.838968          True
# 16    138        7.417362          True
# 17    140        7.431310          True
# 18    145        8.193335          True
# 19    148        8.504295          True
# 20    150        8.303743          True
# 21    152        7.917870          True
# 22    149        6.565367          True
# 23    155        6.644331          True
# 24    158        6.859762          True
# 25    160        6.798172          True
# 26    162        6.628223          True
# 27    165        6.727441          True
# 28    168        6.942225          True
# 29    170        6.871466          True

# %% [markdown]
# ### 6. Detect stable market periods.

# %%
stock_df['Stable_Market'] = (
    stock_df['EWM_Volatility'] < 2
)

print(
    stock_df[
        ['Price', 'EWM_Volatility', 'Stable_Market']
    ]
)
# Out:
#     Price  EWM_Volatility  Stable_Market
# 0     100             NaN          False
# 1     102        1.414214           True
# 2     101        0.903211           True
# 3     105        2.383309          False
# 4     108        3.496965          False
# 5     110        3.991390          False
# 6     115        5.531194          False
# 7     112        4.626282          False
# 8     118        5.501002          False
# 9     120        5.799784          False
# 10    122        5.872792          False
# 11    125        6.172278          False
# 12    123        5.258029          False
# 13    128        5.635803          False
# 14    130        5.771115          False
# 15    135        6.838968          False
# 16    138        7.417362          False
# 17    140        7.431310          False
# 18    145        8.193335          False
# 19    148        8.504295          False
# 20    150        8.303743          False
# 21    152        7.917870          False
# 22    149        6.565367          False
# 23    155        6.644331          False
# 24    158        6.859762          False
# 25    160        6.798172          False
# 26    162        6.628223          False
# 27    165        6.727441          False
# 28    168        6.942225          False
# 29    170        6.871466          False

# %% [markdown]
# ### 7. Compare EWM std vs rolling std.

# %%
stock_df['Rolling_STD'] = (
    stock_df['Price']
    .rolling(window=5)
    .std()
)

stock_df['EWM_STD'] = (
    stock_df['Price']
    .ewm(span=5)
    .std()
)

print(
    stock_df[
        ['Price', 'Rolling_STD', 'EWM_STD']
    ]
)
# Out:
#     Price  Rolling_STD   EWM_STD
# 0     100          NaN       NaN
# 1     102          NaN  1.414214
# 2     101          NaN  0.903211
# 3     105          NaN  2.383309
# 4     108     3.271085  3.496965
# 5     110     3.834058  3.991390
# 6     115     5.263079  5.531194
# 7     112     3.807887  4.626282
# 8     118     3.974921  5.501002
# 9     120     4.123106  5.799784
# 10    122     3.974921  5.872792
# 11    125     4.878524  6.172278
# 12    123     2.701851  5.258029
# 13    128     3.049590  5.635803
# 14    130     3.361547  5.771115
# 15    135     4.658326  6.838968
# 16    138     5.890671  7.417362
# 17    140     5.118594  7.431310
# 18    145     5.594640  8.193335
# 19    148     5.263079  8.504295
# 20    150     5.118594  8.303743
# 21    152     4.690416  7.917870
# 22    149     2.588436  6.565367
# 23    155     2.774887  6.644331
# 24    158     3.701351  6.859762
# 25    160     4.438468  6.798172
# 26    162     5.069517  6.628223
# 27    165     3.807887  6.727441
# 28    168     3.974921  6.942225
# 29    170     4.123106  6.871466

# %% [markdown]
# ### 8. Compare EWM mean vs rolling mean.

# %%
stock_df['Rolling_Mean'] = (
    stock_df['Price']
    .rolling(window=5)
    .mean()
)

stock_df['EWM_Mean'] = (
    stock_df['Price']
    .ewm(span=5)
    .mean()
)

print(
    stock_df[
        ['Price', 'Rolling_Mean', 'EWM_Mean']
    ]
)
# Out:
#     Price  Rolling_Mean    EWM_Mean
# 0     100           NaN  100.000000
# 1     102           NaN  101.200000
# 2     101           NaN  101.105263
# 3     105           NaN  102.723077
# 4     108         103.2  104.748815
# 5     110         105.2  106.667669
# 6     115         107.8  109.617776
# 7     112         110.0  110.444092
# 8     118         112.6  113.029993
# 9     120         115.0  115.394330
# 10    122         117.4  117.621974
# 11    125         119.4  120.100418
# 12    123         121.6  121.071937
# 13    128         123.6  123.389229
# 14    130         125.6  125.597863
# 15    135         128.2  128.736688
# 16    138         130.8  131.827596
# 17    140         134.2  134.553575
# 18    145         137.6  138.037288
# 19    148         141.2  141.359191
# 20    150         144.2  144.240038
# 21    152         147.0  146.827038
# 22    149         148.8  147.551423
# 23    155         150.8  150.034430
# 24    158         152.8  152.689725
# 25    160         154.8  155.126548
# 26    162         156.8  157.417739
# 27    165         160.0  159.945189
# 28    168         162.6  162.630147
# 29    170         165.0  165.086777

# %% [markdown]
# ### 9. Use span=10.

# %%
stock_df['EWM_Span10'] = (
    stock_df['Price']
    .ewm(span=10)
    .mean()
)

print(
    stock_df[
        ['Price', 'EWM_Span10']
    ]
)
# Out:
#     Price  EWM_Span10
# 0     100  100.000000
# 1     102  101.100000
# 2     101  101.059801
# 3     105  102.357921
# 4     108  103.977608
# 5     110  105.541831
# 6     115  107.820870
# 7     112  108.771642
# 8     118  110.779410
# 9     120  112.716252
# 10    122  114.612805
# 11    125  116.688148
# 12    123  117.926970
# 13    128  119.875833
# 14    130  121.812023
# 15    135  124.310597
# 16    138  126.884506
# 17    140  129.335302
# 18    145  132.247758
# 19    148  135.164512
# 20    150  137.902355
# 21    152  140.496951
# 22    149  142.058416
# 23    155  144.430642
# 24    158  146.914254
# 25    160  149.306449
# 26    162  151.624650
# 27    165  154.065389
# 28    168  156.606500
# 29    170  159.047612

# %% [markdown]
# ### 10. Use span=3.

# %%
stock_df['EWM_Span3'] = (
    stock_df['Price']
    .ewm(span=3)
    .mean()
)

print(
    stock_df[
        ['Price', 'EWM_Span3']
    ]
)
# Out:
#     Price   EWM_Span3
# 0     100  100.000000
# 1     102  101.333333
# 2     101  101.142857
# 3     105  103.200000
# 4     108  105.677419
# 5     110  107.873016
# 6     115  111.464567
# 7     112  111.733333
# 8     118  114.872798
# 9     120  117.438905
# 10    122  119.720567
# 11    125  122.360928
# 12    123  122.680503
# 13    128  125.340414
# 14    130  127.670278
# 15    135  131.335195
# 16    138  134.667623
# 17    140  137.333822
# 18    145  141.166918
# 19    148  144.583462
# 20    150  147.291732
# 21    152  149.645867
# 22    149  149.322933
# 23    155  152.161467
# 24    158  155.080734
# 25    160  157.540367
# 26    162  159.770183
# 27    165  162.385092
# 28    168  165.192546
# 29    170  167.596273

# %% [markdown]
# ## 3 — Large Website Traffic Dataset

# %%
traffic_df = pd.DataFrame({
    'Visitors': [
        1000, 1200, 1500, 1700, 1600,
        1800, 2000, 2200, 2100, 2300,
        2500, 2700, 2600, 2800, 3000,
        3200, 3100, 3300, 3500, 3700,
        3600, 3800, 4000, 4200, 4100,
        4300, 4500, 4700, 4900, 5000
    ]
})

print(traffic_df)
# Out:
#     Visitors
# 0       1000
# 1       1200
# 2       1500
# 3       1700
# 4       1600
# 5       1800
# 6       2000
# 7       2200
# 8       2100
# 9       2300
# 10      2500
# 11      2700
# 12      2600
# 13      2800
# 14      3000
# 15      3200
# 16      3100
# 17      3300
# 18      3500
# 19      3700
# 20      3600
# 21      3800
# 22      4000
# 23      4200
# 24      4100
# 25      4300
# 26      4500
# 27      4700
# 28      4900
# 29      5000

# %% [markdown]
# ### 1. Create EWM average visitors.

# %%
traffic_df['EWM_Visitors'] = (
    traffic_df['Visitors']
    .ewm(span=5)
    .mean()
)

print(traffic_df)
# Out:
#     Visitors  EWM_Visitors
# 0       1000   1000.000000
# 1       1200   1120.000000
# 2       1500   1300.000000
# 3       1700   1466.153846
# 4       1600   1517.535545
# 5       1800   1620.751880
# 6       2000   1755.026712
# 7       2200   1909.373513
# 8       2100   1974.612696
# 9       2300   2084.989229
# 10      2500   2224.944174
# 11      2700   2384.526069
# 12      2600   2456.721671
# 13      2800   2571.541093
# 14      3000   2714.687626
# 15      3200   2876.705079
# 16      3100   2951.212341
# 17      3300   3067.553615
# 18      3500   3211.767464
# 19      3700   3374.560599
# 20      3600   3449.722135
# 21      3800   3566.497031
# 22      4000   3711.010898
# 23      4200   3874.016948
# 24      4100   3949.347615
# 25      4300   4066.234830
# 26      4500   4210.825765
# 27      4700   4373.885756
# 28      4900   4549.258543
# 29      5000   4699.506479

# %% [markdown]
# ### 2. Detect recent traffic trend.

# %%
traffic_df['Recent_Trend'] = (
    traffic_df['Visitors']
    .ewm(span=5)
    .mean()
)

print(
    traffic_df[
        ['Visitors', 'Recent_Trend']
    ]
)
# Out:
#     Visitors  Recent_Trend
# 0       1000   1000.000000
# 1       1200   1120.000000
# 2       1500   1300.000000
# 3       1700   1466.153846
# 4       1600   1517.535545
# 5       1800   1620.751880
# 6       2000   1755.026712
# 7       2200   1909.373513
# 8       2100   1974.612696
# 9       2300   2084.989229
# 10      2500   2224.944174
# 11      2700   2384.526069
# 12      2600   2456.721671
# 13      2800   2571.541093
# 14      3000   2714.687626
# 15      3200   2876.705079
# 16      3100   2951.212341
# 17      3300   3067.553615
# 18      3500   3211.767464
# 19      3700   3374.560599
# 20      3600   3449.722135
# 21      3800   3566.497031
# 22      4000   3711.010898
# 23      4200   3874.016948
# 24      4100   3949.347615
# 25      4300   4066.234830
# 26      4500   4210.825765
# 27      4700   4373.885756
# 28      4900   4549.258543
# 29      5000   4699.506479

# %% [markdown]
# ### 3. Detect traffic spikes.

# %%
traffic_df['Traffic_Change'] = (
    traffic_df['Visitors']
    .diff()
)

traffic_df['Traffic_Spike'] = (
    traffic_df['Traffic_Change'] > 300
)

print(
    traffic_df[
        ['Visitors', 'Traffic_Change', 'Traffic_Spike']
    ]
)
# Out:
#     Visitors  Traffic_Change  Traffic_Spike
# 0       1000             NaN          False
# 1       1200           200.0          False
# 2       1500           300.0          False
# 3       1700           200.0          False
# 4       1600          -100.0          False
# 5       1800           200.0          False
# 6       2000           200.0          False
# 7       2200           200.0          False
# 8       2100          -100.0          False
# 9       2300           200.0          False
# 10      2500           200.0          False
# 11      2700           200.0          False
# 12      2600          -100.0          False
# 13      2800           200.0          False
# 14      3000           200.0          False
# 15      3200           200.0          False
# 16      3100          -100.0          False
# 17      3300           200.0          False
# 18      3500           200.0          False
# 19      3700           200.0          False
# 20      3600          -100.0          False
# 21      3800           200.0          False
# 22      4000           200.0          False
# 23      4200           200.0          False
# 24      4100          -100.0          False
# 25      4300           200.0          False
# 26      4500           200.0          False
# 27      4700           200.0          False
# 28      4900           200.0          False
# 29      5000           100.0          False

# %% [markdown]
# ### 4. Detect traffic drops.

# %%
traffic_df['Traffic_Drop'] = (
    traffic_df['Traffic_Change'] < -200
)

print(
    traffic_df[
        ['Visitors', 'Traffic_Change', 'Traffic_Drop']
    ]
)
# Out:
#     Visitors  Traffic_Change  Traffic_Drop
# 0       1000             NaN         False
# 1       1200           200.0         False
# 2       1500           300.0         False
# 3       1700           200.0         False
# 4       1600          -100.0         False
# 5       1800           200.0         False
# 6       2000           200.0         False
# 7       2200           200.0         False
# 8       2100          -100.0         False
# 9       2300           200.0         False
# 10      2500           200.0         False
# 11      2700           200.0         False
# 12      2600          -100.0         False
# 13      2800           200.0         False
# 14      3000           200.0         False
# 15      3200           200.0         False
# 16      3100          -100.0         False
# 17      3300           200.0         False
# 18      3500           200.0         False
# 19      3700           200.0         False
# 20      3600          -100.0         False
# 21      3800           200.0         False
# 22      4000           200.0         False
# 23      4200           200.0         False
# 24      4100          -100.0         False
# 25      4300           200.0         False
# 26      4500           200.0         False
# 27      4700           200.0         False
# 28      4900           200.0         False
# 29      5000           100.0         False

# %% [markdown]
# ### 5. Create EWM std.

# %%
traffic_df['EWM_STD'] = (
    traffic_df['Visitors']
    .ewm(span=5)
    .std()
)

print(traffic_df)
# Out:
#     Visitors  EWM_Visitors  Recent_Trend  Traffic_Change  Traffic_Spike  \
# 0       1000   1000.000000   1000.000000             NaN          False
# 1       1200   1120.000000   1120.000000           200.0          False
# 2       1500   1300.000000   1300.000000           300.0          False
# 3       1700   1466.153846   1466.153846           200.0          False
# 4       1600   1517.535545   1517.535545          -100.0          False
# 5       1800   1620.751880   1620.751880           200.0          False
# 6       2000   1755.026712   1755.026712           200.0          False
# 7       2200   1909.373513   1909.373513           200.0          False
# 8       2100   1974.612696   1974.612696          -100.0          False
# 9       2300   2084.989229   2084.989229           200.0          False
# 10      2500   2224.944174   2224.944174           200.0          False
# 11      2700   2384.526069   2384.526069           200.0          False
# 12      2600   2456.721671   2456.721671          -100.0          False
# 13      2800   2571.541093   2571.541093           200.0          False
# 14      3000   2714.687626   2714.687626           200.0          False
# 15      3200   2876.705079   2876.705079           200.0          False
# 16      3100   2951.212341   2951.212341          -100.0          False
# 17      3300   3067.553615   3067.553615           200.0          False
# 18      3500   3211.767464   3211.767464           200.0          False
# 19      3700   3374.560599   3374.560599           200.0          False
# 20      3600   3449.722135   3449.722135          -100.0          False
# 21      3800   3566.497031   3566.497031           200.0          False
# 22      4000   3711.010898   3711.010898           200.0          False
# 23      4200   3874.016948   3874.016948           200.0          False
# 24      4100   3949.347615   3949.347615          -100.0          False
# 25      4300   4066.234830   4066.234830           200.0          False
# 26      4500   4210.825765   4210.825765           200.0          False
# 27      4700   4373.885756   4373.885756           200.0          False
# 28      4900   4549.258543   4549.258543           200.0          False
# 29      5000   4699.506479   4699.506479           100.0          False
#
#     Traffic_Drop     EWM_STD
# 0          False         NaN
# 1          False  141.421356
# 2          False  254.950976
# 3          False  299.324476
# 4          False  241.059606
# 5          False  245.148922
# 6          False  283.854901
# 7          False  330.574637
# 8          False  285.897957
# 9          False  289.298071
# 10         False  322.033533
# 11         False  363.191409
# 12         False  317.113080
# 13         False  315.773963
# 14         False  342.741238
# 15         False  379.142419
# 16         False  331.094899
# 17         False  326.895646
# 18         False  350.980087
# 19         False  385.149630
# 20         False  336.153130
# 21         False  330.774015
# 22         False  353.754269
# 23         False  387.101825
# 24         False  337.759964
# 25         False  331.976917
# 26         False  354.594000
# 27         False  387.678331
# 28         False  420.813702
# 29         False  417.721754

# %% [markdown]
# ### 6. Detect unstable traffic periods.

# %%
traffic_df['Unstable_Traffic'] = (
    traffic_df['EWM_STD'] > 250
)

print(
    traffic_df[
        ['Visitors', 'EWM_STD', 'Unstable_Traffic']
    ]
)
# Out:
#     Visitors     EWM_STD  Unstable_Traffic
# 0       1000         NaN             False
# 1       1200  141.421356             False
# 2       1500  254.950976              True
# 3       1700  299.324476              True
# 4       1600  241.059606             False
# 5       1800  245.148922             False
# 6       2000  283.854901              True
# 7       2200  330.574637              True
# 8       2100  285.897957              True
# 9       2300  289.298071              True
# 10      2500  322.033533              True
# 11      2700  363.191409              True
# 12      2600  317.113080              True
# 13      2800  315.773963              True
# 14      3000  342.741238              True
# 15      3200  379.142419              True
# 16      3100  331.094899              True
# 17      3300  326.895646              True
# 18      3500  350.980087              True
# 19      3700  385.149630              True
# 20      3600  336.153130              True
# 21      3800  330.774015              True
# 22      4000  353.754269              True
# 23      4200  387.101825              True
# 24      4100  337.759964              True
# 25      4300  331.976917              True
# 26      4500  354.594000              True
# 27      4700  387.678331              True
# 28      4900  420.813702              True
# 29      5000  417.721754              True

# %% [markdown]
# ### 7. Detect stable traffic periods.

# %%
traffic_df['Stable_Traffic'] = (
    traffic_df['EWM_STD'] < 150
)

print(
    traffic_df[
        ['Visitors', 'EWM_STD', 'Stable_Traffic']
    ]
)
# Out:
#     Visitors     EWM_STD  Stable_Traffic
# 0       1000         NaN           False
# 1       1200  141.421356            True
# 2       1500  254.950976           False
# 3       1700  299.324476           False
# 4       1600  241.059606           False
# 5       1800  245.148922           False
# 6       2000  283.854901           False
# 7       2200  330.574637           False
# 8       2100  285.897957           False
# 9       2300  289.298071           False
# 10      2500  322.033533           False
# 11      2700  363.191409           False
# 12      2600  317.113080           False
# 13      2800  315.773963           False
# 14      3000  342.741238           False
# 15      3200  379.142419           False
# 16      3100  331.094899           False
# 17      3300  326.895646           False
# 18      3500  350.980087           False
# 19      3700  385.149630           False
# 20      3600  336.153130           False
# 21      3800  330.774015           False
# 22      4000  353.754269           False
# 23      4200  387.101825           False
# 24      4100  337.759964           False
# 25      4300  331.976917           False
# 26      4500  354.594000           False
# 27      4700  387.678331           False
# 28      4900  420.813702           False
# 29      5000  417.721754           False

# %% [markdown]
# ### 8. Compare EWM vs rolling visitors.

# %%
traffic_df['Rolling_Mean'] = (
    traffic_df['Visitors']
    .rolling(window=5)
    .mean()
)

traffic_df['EWM_Mean'] = (
    traffic_df['Visitors']
    .ewm(span=5)
    .mean()
)

print(
    traffic_df[
        ['Visitors', 'Rolling_Mean', 'EWM_Mean']
    ]
)
# Out:
#     Visitors  Rolling_Mean     EWM_Mean
# 0       1000           NaN  1000.000000
# 1       1200           NaN  1120.000000
# 2       1500           NaN  1300.000000
# 3       1700           NaN  1466.153846
# 4       1600        1400.0  1517.535545
# 5       1800        1560.0  1620.751880
# 6       2000        1720.0  1755.026712
# 7       2200        1860.0  1909.373513
# 8       2100        1940.0  1974.612696
# 9       2300        2080.0  2084.989229
# 10      2500        2220.0  2224.944174
# 11      2700        2360.0  2384.526069
# 12      2600        2440.0  2456.721671
# 13      2800        2580.0  2571.541093
# 14      3000        2720.0  2714.687626
# 15      3200        2860.0  2876.705079
# 16      3100        2940.0  2951.212341
# 17      3300        3080.0  3067.553615
# 18      3500        3220.0  3211.767464
# 19      3700        3360.0  3374.560599
# 20      3600        3440.0  3449.722135
# 21      3800        3580.0  3566.497031
# 22      4000        3720.0  3711.010898
# 23      4200        3860.0  3874.016948
# 24      4100        3940.0  3949.347615
# 25      4300        4080.0  4066.234830
# 26      4500        4220.0  4210.825765
# 27      4700        4360.0  4373.885756
# 28      4900        4500.0  4549.258543
# 29      5000        4680.0  4699.506479

# %% [markdown]
# ### 9.Compare EWM vs expanding visitors.

# %%
traffic_df['Expanding_Mean'] = (
    traffic_df['Visitors']
    .expanding()
    .mean()
)

traffic_df['EWM_Mean'] = (
    traffic_df['Visitors']
    .ewm(span=5)
    .mean()
)

print(
    traffic_df[
        ['Visitors', 'Expanding_Mean', 'EWM_Mean']
    ]
)
# Out:
#     Visitors  Expanding_Mean     EWM_Mean
# 0       1000     1000.000000  1000.000000
# 1       1200     1100.000000  1120.000000
# 2       1500     1233.333333  1300.000000
# 3       1700     1350.000000  1466.153846
# 4       1600     1400.000000  1517.535545
# 5       1800     1466.666667  1620.751880
# 6       2000     1542.857143  1755.026712
# 7       2200     1625.000000  1909.373513
# 8       2100     1677.777778  1974.612696
# 9       2300     1740.000000  2084.989229
# 10      2500     1809.090909  2224.944174
# 11      2700     1883.333333  2384.526069
# 12      2600     1938.461538  2456.721671
# 13      2800     2000.000000  2571.541093
# 14      3000     2066.666667  2714.687626
# 15      3200     2137.500000  2876.705079
# 16      3100     2194.117647  2951.212341
# 17      3300     2255.555556  3067.553615
# 18      3500     2321.052632  3211.767464
# 19      3700     2390.000000  3374.560599
# 20      3600     2447.619048  3449.722135
# 21      3800     2509.090909  3566.497031
# 22      4000     2573.913043  3711.010898
# 23      4200     2641.666667  3874.016948
# 24      4100     2700.000000  3949.347615
# 25      4300     2761.538462  4066.234830
# 26      4500     2825.925926  4210.825765
# 27      4700     2892.857143  4373.885756
# 28      4900     2962.068966  4549.258543
# 29      5000     3030.000000  4699.506479

# %% [markdown]
# ### 10. Create weighted traffic trend.

# %%
traffic_df['EWM_Span7'] = (
    traffic_df['Visitors']
    .ewm(span=7)
    .mean()
)

print(
    traffic_df[
        ['Visitors', 'EWM_Span7']
    ]
)
# Out:
#     Visitors    EWM_Span7
# 0       1000  1000.000000
# 1       1200  1114.285714
# 2       1500  1281.081081
# 3       1700  1434.285714
# 4       1600  1488.604353
# 5       1800  1583.308583
# 6       2000  1703.528915
# 7       2200  1841.454854
# 8       2100  1911.338318
# 9       2300  2014.301985
# 10      2500  2141.081018
# 11      2700  2285.381682
# 12      2600  2365.950353
# 13      2800  2476.431309
# 14      3000  2609.096346
# 15      3200  2758.317846
# 16      3100  2844.385349
# 17      3300  2958.934809
# 18      3500  3094.775479
# 19      3700  3246.562960
# 20      3600  3335.132875
# 21      3800  3451.557335
# 22      4000  3588.851681
# 23      4200  3741.792220
# 24      4100  3831.411608
# 25      4300  3948.624862
# 26      4500  4086.527021
# 27      4700  4239.943973
# 28      4900  4404.997280
# 29      5000  4553.774529
