# %% [markdown]
# # NUMPY JOINING ASSIGNMENT

# %% [markdown]
# ### DAY : 08

# %% [markdown]
# ## A. ARRAY JOINING

# %% [markdown]
# ## CONCATENATION()

# %% [markdown]
# ### BASIC questions

# %%
import numpy as np

# %%
A = np.array([1, 2, 3])
B = np.array([44, 55, 66])

# %%
print("Array A :",A)
print("Array B : ",B)
# Out:
# Array A : [1 2 3]
# Array B :  [44 55 66]

# %% [markdown]
# #### 1.Using concatenation, form a single array by joining A and B.

# %%
# data = np.concatenate(A,B)

# %%
np.concatenate((A,B))
# Out:
# array([ 1,  2,  3, 44, 55, 66])

# %% [markdown]
# #### 2. Create a new array by joining B followed by A.

# %%
new_array = np.concatenate((B,A))
new_array
# Out:
# array([44, 55, 66,  1,  2,  3])

# %% [markdown]
# #### 3. Construct an array by repeating A twice and then adding B.

# %%
reapeted_A = np.tile(A,2)
print("Repeated Array A : ",reapeted_A)
new_array = np.concatenate((reapeted_A,B))
print("Combined Array : ",new_array)
# Out:
# Repeated Array A :  [1 2 3 1 2 3]
# Combined Array :  [ 1  2  3  1  2  3 44 55 66]

# %%
#best way
np.concatenate((A,A,B))
# Out:
# array([ 1,  2,  3,  1,  2,  3, 44, 55, 66])

# %% [markdown]
# #### 4. Combine A and B in alternating order (A, B, A).

# %%
np.concatenate((A,B,A))
# Out:
# array([ 1,  2,  3, 44, 55, 66,  1,  2,  3])

# %% [markdown]
# #### 5. Merge A and B and find the total number of elements.

# %%
np.concatenate((A,B)).size
# Out:
# 6

# %% [markdown]
# #### 6. Create a final array by joining B three times.

# %%
np.concatenate((B,B,B))
# Out:
# array([44, 55, 66, 44, 55, 66, 44, 55, 66])

# %% [markdown]
# #### 7. Join A and B and check whether the result is sorted or not.

# %%
data = np.concatenate((A,B))
print(data)
is_soarted = np.all(data[:-1]<=data[1:])
print("Is sorted :",is_soarted)
# Out:
# [ 1  2  3 44 55 66]
# Is sorted : True

# %% [markdown]
# #### 8. Form a dataset by combining A and B and compare lengths before/after join.

# %%
print("Length of A:",A.size)
print("Length of B : ",B.size)
combined_data = np.concatenate((A,B))
print("Length of Combined Data :",combined_data.size)
# Out:
# Length of A: 3
# Length of B :  3
# Length of Combined Data : 6

# %% [markdown]
# #### 9. Create a reversed combined array using A and B.

# %%
data = np.concatenate((A,B))[::-1]
data
# Out:
# array([66, 55, 44,  3,  2,  1])

# %% [markdown]
# #### 10. Join A and B and compute sum of all elements in final array.

# %%
final_data = np.concatenate((A,B)).sum()
print(final_data)
# Out:
# 171

# %% [markdown]
# ### ADVANCED (5 QUESTIONS)

# %%
X = [[1, 2], [3, 4]]
Y = [[55, 66], [77, 88]]
x = np.array(X)
y = np.array(Y)
print("Array X :",x,sep="\n")
print("Array Y :",y,sep="\n")
# Out:
# Array X :
# [[1 2]
#  [3 4]]
# Array Y :
# [[55 66]
#  [77 88]]

# %% [markdown]
# #### 1. Combine X and Y vertically and explain resulting shape.

# %%
data = np.concatenate((x,y),axis=0)
data
# Out:
# array([[ 1,  2],
#        [ 3,  4],
#        [55, 66],
#        [77, 88]])

# %%
print("Shape - (rows,cols)")
print("Shape of x :",x.shape)
print("Shape of y :",y.shape)
print("Shape of combined :",data.shape)
print("Here combined veritically means row vise, so new shape is rows of x + rows of y and column are same ")

print("Note :vertically join valid when column of both array same ")
# Out:
# Shape - (rows,cols)
# Shape of x : (2, 2)
# Shape of y : (2, 2)
# Shape of combined : (4, 2)
# Here combined veritically means row vise, so new shape is rows of x + rows of y and column are same
# Note :vertically join valid when column of both array same

# %% [markdown]
# #### 2. Combine X and Y horizontally and explain difference from vertical join.

# %%
hdata = np.concatenate((x,y),axis =1)
hdata
# Out:
# array([[ 1,  2, 55, 66],
#        [ 3,  4, 77, 88]])

# %%
print("Verical join means row vise adding but column of all array must same otherwise fail join ")
print("Vertical join result shape: (rows+all adding rows ) same column size")
print("-"*50)
print("Horizontal Join means column vise adding but rows of all adiing must be same othervise fail join")
print("Horizontal join result shape (rows, coulumn+all other arrys adding new columns)")
# Out:
# Verical join means row vise adding but column of all array must same otherwise fail join
# Vertical join result shape: (rows+all adding rows ) same column size
# --------------------------------------------------
# Horizontal Join means column vise adding but rows of all adiing must be same othervise fail join
# Horizontal join result shape (rows, coulumn+all other arrys adding new columns)

# %% [markdown]
# #### 3. Create a dataset by joining X, Y, and X again vertically.

# %%
np.concatenate((x,y,x),axis=0)
# Out:
# array([[ 1,  2],
#        [ 3,  4],
#        [55, 66],
#        [77, 88],
#        [ 1,  2],
#        [ 3,  4]])

# %% [markdown]
# #### 4. Join Y and X horizontally and compute row-wise sum of final matrix.

# %%
hdata = np.concatenate((y,x),axis=1)
hdata.sum(axis=1)
# Out:
# array([124, 172])

# %% [markdown]
# #### 5. Merge X and Y into a single matrix and verify total elements count.

# %%
mdata = np.concatenate((x,y),axis=0)
print("Total Elements : ",mdata.size)
# Out:
# Total Elements :  8

# %% [markdown]
# ### REAL WORLD (5 QUESTIONS)

# %%
Math_Marks = np.array([50, 60])
Science_Marks = np.array([70, 80])

Sales_Jan = np.array([100, 200])
Sales_Feb = np.array([150, 250])

Sensor_A = np.array([0.1, 0.2])
Sensor_B = np.array([0.3, 0.4])

Login_Day1 = np.array([5, 6])
Login_Day2 = np.array([7, 8])

# %% [markdown]
# #### 1 . Combine Math and Science marks into a single student report.

# %%
sub_marks = np.concatenate((Math_Marks,Science_Marks))
sub_marks
# Out:
# array([50, 60, 70, 80])

# %%
submarks1 = np.concatenate((Math_Marks.reshape(-1,1),Science_Marks.reshape(-1,1)),axis=1)
submarks1
# Out:
# array([[50, 70],
#        [60, 80]])

# %% [markdown]
# #### 2. Merge January and February sales data and compute total sales.

# %%
complete_sales = np.concatenate((Sales_Jan,Sales_Feb))
complete_sales
# Out:
# array([100, 200, 150, 250])

# %% [markdown]
# #### 3. Combine Sensor A and Sensor B readings into one dataset.

# %%
np.concatenate((Sensor_A,Sensor_B))
# Out:
# array([0.1, 0.2, 0.3, 0.4])

# %% [markdown]
# #### 4. Merge login activity of Day1 and Day2 into a full activity log.

# %%
login_acti = np.concatenate((Login_Day1,Login_Day2))
login_acti
# Out:
# array([5, 6, 7, 8])

# %% [markdown]
# ## B. ARRAY STACKING

# %% [markdown]
# ### 1. np.stack()

# %%
a1 = np.array([1, 2, 3])
b1 = np.array([4, 5, 6])

# %% [markdown]
# #### 1. Stack A and B along a new axis and describe the shape.

# %%
stack_data = np.stack((a1,b1))
print("Stacked Data :",stack_data,sep='\n')
print("Shape :",stack_data.shape)
# Out:
# Stacked Data :
# [[1 2 3]
#  [4 5 6]]
# Shape : (2, 3)

# %% [markdown]
# #### 2. Stack A and B such that they form rows in a matrix.

# %%
np.stack((a1,b1))
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# #### 3. Stack A and B such that they form columns.

# %%
np.stack((a1,b1),axis=1)
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %% [markdown]
# #### 4. `Stack A, B, and A again and describe structure.

# %%
data = np.stack((a1,b1,a1))
print(data)
print(data.shape)
print(data.ndim)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [1 2 3]]
# (3, 3)
# 2

# %% [markdown]
# #### 5. Stack B, A, B and count total elements.

# %%
print("Total Elements :",np.stack((b1,a1,b1)).size)
# Out:
# Total Elements : 9

# %% [markdown]
# ##### 6. Stack A with itself and compare with original.

# %%
print(a1)
print("-"*10)
print(np.stack((a1,a1)))
# Out:
# [1 2 3]
# ----------
# [[1 2 3]
#  [1 2 3]]

# %% [markdown]
# #### 7. Stack A and B and identify number of dimensions.

# %%
print("No of Dim :",np.stack((a1,b1)).ndim)
# Out:
# No of Dim : 2

# %% [markdown]
# #### 8. Stack A, B and find sum of resulting array.

# %%
result = np.stack((a1,b1))
print("Sum Of result :",result.sum())
# Out:
# Sum Of result : 21

# %% [markdown]
# #### 9. Stack A and B and extract first stacked block.

# %%
stdata = np.stack((a1,b1))
print("First Block :",stdata[0])
# Out:
# First Block : [1 2 3]

# %% [markdown]
# #### 10 . Compare stacking A & B vs simple joining.

# %%
print("Stacked Data : ",np.stack((a1,b1)),sep="\n")
print("-"*50)
print("Simple Joinning :",np.concatenate((a1,b1)))
# Out:
# Stacked Data :
# [[1 2 3]
#  [4 5 6]]
# --------------------------------------------------
# Simple Joinning : [1 2 3 4 5 6]

# %% [markdown]
# ### ADVANCED (2D ARRAYS – 5)

# %%
 x1= np.array([[1,2],[3,4]])
 x2= np.array([[5,6],[7,8]])

# %% [markdown]
# #### 1. Stack X and Y along a new axis and describe 3D shape.

# %%
sdata = np.stack((x1,x2))
print(sdata)
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]

# %%
print(sdata.shape)
# Out:
# (2, 2, 2)

# %% [markdown]
# #### 2. Stack X and Y and identify number of layers formed.

# %%
stdata = np.stack((x1,x2))
print(stdata)
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]

# %%
print("Total Layer:",stdata.shape[0])
# Out:
# Total Layer: 2

# %% [markdown]
# #### 3. Stack X, Y, X and compute total number of elements.

# %%
np.stack((x1,x2,x1)).size
# Out:
# 12

# %% [markdown]
# #### 4. Stack Y, X and extract first layer.

# %%
stdata = np.stack((x2,x1))
print(stdata[0,...])
# Out:
# [[5 6]
#  [7 8]]

# %%
stdata
# Out:
# array([[[5, 6],
#         [7, 8]],
#
#        [[1, 2],
#         [3, 4]]])

# %% [markdown]
# #### 5. Stack matrices and analyze how dimension increases.

# %%
print("x1 dime..:",x1.ndim)
print("x2 dime..: ",x2.ndim)
print("Stacked dim..:",np.stack((x2,x1)).ndim)
# Out:
# x1 dime..: 2
# x2 dime..:  2
# Stacked dim..: 3

# %% [markdown]
# ### REAL WORLD

# %%
Temperature = np.array([30, 32, 35])
Humidity = np.array([60, 65, 70])

# %% [markdown]
# #### 1. Stack temperature and humidity to create weather dataset.

# %%
weather_data = np.stack((Temperature,Humidity),axis =1)
weather_data
# Out:
# array([[30, 60],
#        [32, 65],
#        [35, 70]])

# %% [markdown]
# #### 2. Represent each day as a stacked data point.

# %%
data = np.stack((Temperature,Humidity),axis =1)
i=1
for r in data:
    print("Day",i," :",r )
    i+=1
# Out:
# Day 1  : [30 60]
# Day 2  : [32 65]
# Day 3  : [35 70]

# %% [markdown]
# #### 3. Stack multiple features into ML input structure.

# %%
np.stack((Temperature,Humidity),axis=1)
# Out:
# array([[30, 60],
#        [32, 65],
#        [35, 70]])

# %% [markdown]
# #### 4. Combine two feature vectors into model-ready data.

# %%
data = np.stack((Temperature,Humidity))
data
# Out:
# array([[30, 32, 35],
#        [60, 65, 70]])

# %% [markdown]
# # 2. np.vstack()

# %% [markdown]
# #### BASIC (1D ARRAYS – 10)

# %%
A = np.array([1, 2, 3])
B = np.array([4, 5, 6])

# %% [markdown]
# #### 1. Stack A and B vertically to form rows.

# %%
np.vstack((A,B))
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# #### 2. Stack B above A and compare result.

# %%
np.vstack((B,A))
# Out:
# array([[4, 5, 6],
#        [1, 2, 3]])

# %% [markdown]
# #### 3. Stack A twice vertically.

# %%
np.vstack((A,A))
# Out:
# array([[1, 2, 3],
#        [1, 2, 3]])

# %% [markdown]
# #### 4. Stack A, B, A and count rows.

# %%
np.vstack((A,B,A)).shape[0]
# Out:
# 3

# %% [markdown]
# #### 5. Stack B three times and count rows.

# %%
np.vstack((B,B,B)).shape[0]
# Out:
# 3

# %% [markdown]
# #### 6. Stack A and B and compute row-wise sum.

# %%
np.vstack((A,B)).sum(axis=1)
# Out:
# array([ 6, 15])

# %% [markdown]
# #### 7. Stack A and B and extract second row.

# %%
np.vstack((A,B))[1]
# Out:
# array([4, 5, 6])

# %% [markdown]
# #### 8.Stack A and B and find number of rows.

# %%
np.vstack((A,B)).shape[0]
# Out:
# 2

# %% [markdown]
# #### 9. Stack A and B and compare with stack(axis=0).

# %%
data1 = np.vstack((A,B))
data2 = np.stack((A,B),axis=0)
print(data1)
print("-"*18)
print(data2)
# Out:
# [[1 2 3]
#  [4 5 6]]
# ------------------
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# #### 10. Stack A and B and identify row structure.

# %%
data = np.vstack((A,B))
data
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# ### ADVANCED (2D ARRAYS )

# %%
x = np.array([[1,2],[3,4]])
y = np.array([[5,6],[7,8]])

# %%
x
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
y
# Out:
# array([[5, 6],
#        [7, 8]])

# %% [markdown]
# #### 1.Stack X and Y vertically and describe new shape.

# %%
data = np.vstack((x,y))
data
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6],
#        [7, 8]])

# %%
data.shape
# Out:
# (4, 2)

# %% [markdown]
# #### 2. Stack Y and X and compute column-wise sum.

# %%
data = np.vstack((y,x))
data.sum(axis=0)
# Out:
# array([16, 20])

# %% [markdown]
# #### 3.Stack X, Y, X and find row-wise max.

# %%
data = np.vstack((x,y,x))
data.sum(axis=1)
# Out:
# array([ 3,  7, 11, 15,  3,  7])

# %% [markdown]
# #### 4. Stack matrices and count total rows.

# %%
np.vstack((x,y)).shape[0]
# Out:
# 4

# %% [markdown]
# ### REAL WORLD

# %%
Day1_Sales =np.array( [100, 200, 300])
Day2_Sales =np.array( [150, 250, 350])

# %%
Day1_Sales
# Out:
# array([100, 200, 300])

# %%
Day2_Sales
# Out:
# array([150, 250, 350])

# %% [markdown]
# #### 1. Stack daily sales to create time-series dataset.

# %%
dataset = np.vstack((Day1_Sales,Day2_Sales))
dataset
# Out:
# array([[100, 200, 300],
#        [150, 250, 350]])

# %% [markdown]
# #### 2. Represent each day as a row.

# %%
day =1
for r in np.vstack((Day1_Sales,Day2_Sales)):
    print(f"Day {day} : {r}")
    day+=1
# Out:
# Day 1 : [100 200 300]
# Day 2 : [150 250 350]

# %% [markdown]
# #### 3.Stack multiple days and compute daily totals.

# %%
data = np.vstack((Day1_Sales,Day2_Sales))
day= 1
for r in data:
    print(f"Day {day} : Total Sales : {r.sum()}")
# Out:
# Day 1 : Total Sales : 600
# Day 1 : Total Sales : 750

# %% [markdown]
# #### 4. Combine weekly sales data vertically.

# %%
data = np.vstack((Day1_Sales,Day2_Sales))
data
# Out:
# array([[100, 200, 300],
#        [150, 250, 350]])

# %% [markdown]
# # 3. np.hstack()2

# %%
BASIC (1D ARRAYS – 10)
# Out:
#   Cell In[85], line 1
#     BASIC (1D ARRAYS – 10)
#            ^
# SyntaxError: invalid decimal literal

# %%
A = np.array([1, 2, 3])
B = np.array([4, 5, 6])
print("Array A:",A)
print("Array B : ",B)
# Out:
# Array A: [1 2 3]
# Array B :  [4 5 6]

# %% [markdown]
# #### 1 .Stack A and B horizontally.

# %%
data = np.hstack((A,B))
data
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# #### 2. Stack B and A and compare results.

# %%
data = np.hstack((A,B))
print("A :",A)
print("B :",B)
print("Stacked Data :",data)
# Out:
# A : [1 2 3]
# B : [4 5 6]
# Stacked Data : [1 2 3 4 5 6]

# %% [markdown]
# #### 3. Stack A twice horizontally.

# %%
np.hstack((A,A))
# Out:
# array([1, 2, 3, 1, 2, 3])

# %% [markdown]
# #### 4. Stack A, B, A and count elements.

# %%
data = np.hstack((A,B,A))
print("Data :",data)
print("Total Elements :",data.size)
# Out:
# Data : [1 2 3 4 5 6 1 2 3]
# Total Elements : 9

# %% [markdown]
# #### 5. Stack B three times.

# %%
data = np.hstack((B,B,B))
print(data)
# Out:
# [4 5 6 4 5 6 4 5 6]

# %% [markdown]
# #### 6. Stack A and B and compute total length.

# %%
data = np.hstack((A,B))
print("Data :",data)
print("Total Length : ",data.size)
# Out:
# Data : [1 2 3 4 5 6]
# Total Length :  6

# %% [markdown]
# #### 7. Stack A and B and extract first half.

# %%
data = np.hstack((A,B))
size = data.size
data[:size//2]
# Out:
# array([1, 2, 3])

# %% [markdown]
# #### 8. Stack A and B and extract last value.

# %%
data = np.hstack((A,B))
print("Last value :",data[-1])
# Out:
# Last value : 6

# %% [markdown]
# #### 9. Compare result with simple joining.

# %%
simpl_join = np.concatenate((A,B))
stackData = np.hstack((A,B))
print("Data 1: ",simpl_join)
print("Data 2: ",stackData)
print("Compare : ",simpl_join==stackData)
# Out:
# Data 1:  [1 2 3 4 5 6]
# Data 2:  [1 2 3 4 5 6]
# Compare :  [ True  True  True  True  True  True]

# %% [markdown]
# #### 10 . Identify shape after stacking.

# %%
data = np.vstack((A,B))
data.shape
# Out:
# (2, 3)

# %% [markdown]
# ### ADVANCED (2D ARRAYS – 5)

# %%
x = np.array([[1,2],[3,4]])
y = np.array( [[5,6],[7,8]])
print("X array :",x,sep='\n')
print("Y array : ",y,sep ='\n')
# Out:
# X array :
# [[1 2]
#  [3 4]]
# Y array :
# [[5 6]
#  [7 8]]

# %% [markdown]
# #### 1. Stack X and Y horizontally and describe shape.

# %%
data = np.hstack((x,y))
data.shape
# Out:
# (2, 4)

# %% [markdown]
# #### 2.Stack Y and X and compute row sums.

# %%
data = np.hstack((x,y))
data.sum(axis=1)
# Out:
# array([14, 22])

# %%
data
# Out:
# array([[1, 2, 5, 6],
#        [3, 4, 7, 8]])

# %% [markdown]
# #### 3. Stack X, Y, X and count columns.

# %%
data = np.hstack((x,y,x))
total_elements = data.size
print("Total elements :",total_elements)
# Out:
# Total elements : 12

# %% [markdown]
# #### 4. Stack matrices and find max per row.

# %%
data = np.hstack((x,y))
data.max(axis=1)
# Out:
# array([6, 8])

# %% [markdown]
# #### 5. Interpret columns as features.

# %%
data = np.hstack((x,y))
data.shape
# Out:
# (2, 4)

# %%
data
# Out:
# array([[1, 2, 5, 6],
#        [3, 4, 7, 8]])

# %%
fea=0
for a in range(data.shape[1]):
    print(f"Feature col {a} : {data[:,a]}")
# Out:
# Feature col 0 : [1 3]
# Feature col 1 : [2 4]
# Feature col 2 : [5 7]
# Feature col 3 : [6 8]

# %% [markdown]
# # 4. np.dstack()

# %% [markdown]
# ### BASIC (1D → 2D/3D )

# %%
A = np.array([[1,2],[3,4]])
B = np.array([[5,6],[7,8]])
print("Array A :",A,sep="\n")
print("Array B : ",B,sep='\n')
# Out:
# Array A :
# [[1 2]
#  [3 4]]
# Array B :
# [[5 6]
#  [7 8]]

# %% [markdown]
# #### 1. Stack A and B along depth dimension.

# %%
data = np.dstack((A,B))
data
# Out:
# array([[[1, 5],
#         [2, 6]],
#
#        [[3, 7],
#         [4, 8]]])

# %% [markdown]
# #### 2. Identify number of layers formed.

# %%
data = np.dstack((A,B))
data.shape[0]
# Out:
# 2

# %% [markdown]
# #### 3. Stack A, B, A and count depth layers.

# %%
data = np.dstack((A,B,A))
data.shape[0]
# Out:
# 2

# %% [markdown]
# #### 4. Stack B twice and analyze structure.

# %%
data = np.dstack((B,B))
data.shape
# Out:
# (2, 2, 2)

# %% [markdown]
# #### 5.Extract first depth layer.

# %%
data = np.dstack((A,B))
data[0]
# Out:
# array([[1, 5],
#        [2, 6]])

# %% [markdown]
# #### 6. Extract second depth layer.

# %%
data[1]
# Out:
# array([[3, 7],
#        [4, 8]])

# %% [markdown]
# #### 7. Compute total elements after stacking.

# %%
data = np.dstack((A,B))
data.size
# Out:
# 8

# %% [markdown]
# #### 8. Compare with vertical stacking.

# %%
data = np.dstack((A,B))
data2 = np.vstack((A,B))
print("Depth vise stacking : ")
print(data)
print("Vertical stacking : ")
print(data2)
# Out:
# Depth vise stacking :
# [[[1 5]
#   [2 6]]
#
#  [[3 7]
#   [4 8]]]
# Vertical stacking :
# [[1 2]
#  [3 4]
#  [5 6]
#  [7 8]]

# %% [markdown]
# #### 9. Compare with horizontal stacking.

# %%
data = np.dstack((A,B))
data2 = np.hstack((A,B))
print("Depth vise stacking : ")
print(data)
print("Horizonatal stacking : ")
print(data2)
# Out:
# Depth vise stacking :
# [[[1 5]
#   [2 6]]
#
#  [[3 7]
#   [4 8]]]
# Horizonatal stacking :
# [[1 2 5 6]
#  [3 4 7 8]]

# %% [markdown]
# #### 10. Identify final dimension.

# %%
data = np.dstack((A,B))
data.ndim
# Out:
# 3

# %% [markdown]
# # 5. np.column_stack()

# %% [markdown]
# ### BASIC (1D ARRAYS – 10)

# %%
A = np.array([1, 2, 3])
B = np.array([4, 5, 6])
print("Array  A : ",A)
print("Array B :",B)
# Out:
# Array  A :  [1 2 3]
# Array B : [4 5 6]

# %% [markdown]
# #### 1.Stack A and B as columns.

# %%
 data = np.column_stack((A,B))
data
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %% [markdown]
# #### 2. Identify number of columns.

# %%
data = np.column_stack((A,B))
data.shape[1]
# Out:
# 2

# %% [markdown]
# #### 3. Extract first column.

# %%
data = np.column_stack((A,B))
data[...,0]
# Out:
# array([1, 2, 3])

# %% [markdown]
# #### 4. Extract second column.

# %%
data = np.column_stack((A,B))
data[...,1]
# Out:
# array([4, 5, 6])

# %% [markdown]
# #### 5 .Compute column-wise sum.

# %%
data = np.column_stack((A,B))
data.sum(axis=0)
# Out:
# array([ 6, 15])

# %% [markdown]
# #### 6.Stack A twice as columns.

# %%
data = np.column_stack((A,A))
data
# Out:
# array([[1, 1],
#        [2, 2],
#        [3, 3]])

# %% [markdown]
# #### 7.Stack B twice.

# %%
data = np.column_stack((B,B))
data
# Out:
# array([[4, 4],
#        [5, 5],
#        [6, 6]])

# %% [markdown]
# #### 8. Stack A, B, A.

# %%
data = np.column_stack((A,B,A))
data
# Out:
# array([[1, 4, 1],
#        [2, 5, 2],
#        [3, 6, 3]])

# %% [markdown]
# ####  9. Identify shape after stacking.

# %%
data = np.column_stack((A,B))
data.shape
# Out:
# (3, 2)

# %% [markdown]
# #### 10 . Compare with hstack.

# %%
cdata = np.column_stack((A,B))
hdata = np.hstack((A,B))
print("Column Stacking :")
print(cdata)
print("-"*10)
print("H stacking : ")
print(hdata)
# Out:
# Column Stacking :
# [[1 4]
#  [2 5]
#  [3 6]]
# ----------
# H stacking :
# [1 2 3 4 5 6]

# %% [markdown]
# ### ADVANCED (2D ARRAYS )

# %%
x= np.array([[10], [20], [30]])
y = np.array([[40], [50], [60]])
print("Array x :",x,sep='\n')
print("Dimentiona of X :",x.ndim)
print("Array y : ",y,sep='\n')
print("Dimention of Y : ",y.ndim)
# Out:
# Array x :
# [[10]
#  [20]
#  [30]]
# Dimentiona of X : 2
# Array y :
# [[40]
#  [50]
#  [60]]
# Dimention of Y :  2

# %% [markdown]
# #### 1. Create feature matrix using column stacking.

# %%
data = np.column_stack((x,y))
total_col = data.shape[1]
for a in range(total_col):
    print("Feature 1 : ",data[:,a])
# Out:
# Feature 1 :  [10 20 30]
# Feature 1 :  [40 50 60]

# %% [markdown]
# #### 2. Compute column-wise mean.

# %%
data = np.column_stack((x,y))
data.sum(axis=0)
# Out:
# array([ 60, 150])

# %% [markdown]
# #### 3. Stack multiple arrays into dataset.

# %%
dataset = np.column_stack((x,y))
dataset
# Out:
# array([[10, 40],
#        [20, 50],
#        [30, 60]])

# %% [markdown]
# #### 4.Extract column vectors.

# %%
data = np.column_stack((x,y))
total_col = data.shape[1]
for a in range(total_col):
    print(f"Vector {a+1} : {data[...,a]}")
# Out:
# Vector 1 : [10 20 30]
# Vector 2 : [40 50 60]

# %% [markdown]
# # 6. np.row_stack()

# %% [markdown]
# ### BASIC (1D ARRAYS – 10)

# %%
A = np.array([1, 2, 3])
B = np.array([4, 5, 6])
print("Array A :",A)
print("Array B ",B)
# Out:
# Array A : [1 2 3]
# Array B  [4 5 6]

# %% [markdown]
# #### 1.Stack A and B as rows.

# %%
data = np.row_stack((A,B))
data
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_9008\618378719.py:1: DeprecationWarning: `row_stack` alias is deprecated. Use `np.vstack` directly.
#   data = np.row_stack((A,B))
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# #### 2.Identify number of rows.

# %%
data.shape[0]
# Out:
# 2

# %% [markdown]
# #### 3. Extract first row.

# %%
data[0]
# Out:
# array([1, 2, 3])

# %% [markdown]
# #### 4. Extract second row.

# %%
data[1]
# Out:
# array([4, 5, 6])

# %% [markdown]
# #### 5.Compute row-wise sum.

# %%
data.sum(1) # sum(1) means  - sum(axis=1)
# Out:
# array([ 6, 15])

# %% [markdown]
# #### 6. Stack A twice.

# %%
data = np.row_stack((A,A))
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_9008\4148979092.py:1: DeprecationWarning: `row_stack` alias is deprecated. Use `np.vstack` directly.
#   data = np.row_stack((A,A))

# %%
data
# Out:
# array([[1, 2, 3],
#        [1, 2, 3]])

# %% [markdown]
# #### 7.Stack B twice.

# %%
data = np.row_stack((B,B))
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_9008\4126919841.py:1: DeprecationWarning: `row_stack` alias is deprecated. Use `np.vstack` directly.
#   data = np.row_stack((B,B))

# %%
data
# Out:
# array([[4, 5, 6],
#        [4, 5, 6]])

# %% [markdown]
# #### 8. Stack A, B, A.

# %%
data = np.row_stack((A,B,A))
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_9008\1551171226.py:1: DeprecationWarning: `row_stack` alias is deprecated. Use `np.vstack` directly.
#   data = np.row_stack((A,B,A))

# %%
data
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [1, 2, 3]])

# %% [markdown]
# #### 9 .Identify shape.

# %%
data = np.row_stack((A,B))
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_9008\423678399.py:1: DeprecationWarning: `row_stack` alias is deprecated. Use `np.vstack` directly.
#   data = np.row_stack((A,B))

# %%
data.shape
# Out:
# (2, 3)

# %% [markdown]
# #### 10 . Compare with vstack.

# %%
rstdata = np.row_stack((A,B))
# Out:
# C:\Users\Omkar Yallurkar\AppData\Local\Temp\ipykernel_9008\274890968.py:1: DeprecationWarning: `row_stack` alias is deprecated. Use `np.vstack` directly.
#   rstdata = np.row_stack((A,B))

# %%
rstdata
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
vsdata = np.vstack((A,B))

# %%
vsdata
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [raw]
# row_stack() and vstack() both are work same
# row_stack() is older feature
# vstack() is new feature
