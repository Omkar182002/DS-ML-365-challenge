# %% [markdown]
# # NumPy Set Operations

# %%
import numpy as np

# %% [markdown]
# ## 1. np.union1d()

# %% [markdown]
# #### 1. Find the union of two arrays [1,2,3] and [3,4,5].

# %%
a= np.array([1,2,3])
b = np.array([3,4,5])
print(np.union1d(a,b))
# Out:
# [1 2 3 4 5]

# %% [markdown]
# #### 2. Find unique combined elements from [5,6,7] and [7,8,9].

# %%
print(np.union1d([5,6,7],[7,8,9]))
# Out:
# [5 6 7 8 9]

# %% [markdown]
# #### 3. Find union of [10,20] and [20,30,40].

# %%
print(np.union1d([10,20],[20,30,40]))
# Out:
# [10 20 30 40]

# %% [markdown]
# #### 4. Combine [1,1,2] and [2,3,3] into unique elements.

# %%
print(np.union1d([1,1,2],[2,3,3]))
# Out:
# [1 2 3]

# %% [markdown]
# #### 5. Find union of [100,200] and [300,400].

# %%
print(np.union1d([100,200],[300,400]))
# Out:
# [100 200 300 400]

# %% [markdown]
# #### 6. Merge [2,4,6] and [1,3,5] into sorted unique array.

# %%
np.union1d([2,4,6],[1,3,5])
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# #### 7. Find union of negative arrays [-1,-2] and [-2,-3].

# %%
np.union1d([-1,-2],[-2,-3])
# Out:
# array([-3, -2, -1])

# %% [markdown]
# #### 8. Combine [0,1,2] and [2,3,4].

# %%
print(np.union1d([0,1,2],[2,3,4]))
# Out:
# [0 1 2 3 4]

# %% [markdown]
# #### 9. Find union of [9,8,7] and [7,6,5].

# %%
print(np.union1d([9,8,7],[7,6,5]))
# Out:
# [5 6 7 8 9]

# %% [markdown]
# #### 10. Combine [11,12] and [12,13,14].

# %%
print(np.union1d([11,12],[12,13,14]))
# Out:
# [11 12 13 14]

# %% [markdown]
# #

# %% [markdown]
# ## 2. np.intersect1d()

# %% [markdown]
# #### 1. Find common elements in [1,2,3] and [2,3,4].

# %%
print(np.intersect1d([1,2,3],[2,3,4]))
# Out:
# [2 3]

# %% [markdown]
# #### 2. Find intersection of [5,6,7] and [7,8,9].

# %%
print(np.intersect1d([5,6,7],[7,8,9]))
# Out:
# [7]

# %% [markdown]
# #### 3. Find common values in [10,20,30] and [20,40].

# %%
print(np.intersect1d([10,20,30],[20,30]))
# Out:
# [20 30]

# %% [markdown]
# #### 4. Find intersection of [1,1,2] and [2,2,3].

# %%
print(np.intersect1d([1,1,2],[2,2,3]))
# Out:
# [2]

# %% [markdown]
# #### 5. Find common elements in [100,200] and [300,200].

# %%
print(np.intersect1d([100,200],[300,200]))
# Out:
# [200]

# %% [markdown]
# #### 6. Find intersection of [2,4,6] and [1,3,5].

# %%
print(np.intersect1d([2,4,6],[1,3,5]))
# Out:
# []

# %% [markdown]
# #### 7. Find common elements in [-1,-2] and [-2,-3].

# %%
print(np.intersect1d([-1,-2],[-2,-3]))
# Out:
# [-2]

# %% [markdown]
# #### 8. Find intersection of [0,1,2] and [2,3,4].

# %%
print(np.intersect1d([0,1,2],[2,3,4]))
# Out:
# [2]

# %% [markdown]
# #### 9. Find common values in [9,8,7] and [7,6,5].

# %%
print(np.intersect1d([9,8,7],[7,6,5]))
# Out:
# [7]

# %% [markdown]
# #### 10. Find intersection of [11,12] and [12,13,14].

# %%
print(np.intersect1d([11,12],[12,13,14]))
# Out:
# [12]

# %% [markdown]
# #

# %% [markdown]
# ## 3. np.setdiff1d()

# %% [markdown]
# #### 1.Find elements in [1,2,3] not in [2,3].

# %%
print(np.setdiff1d([1,2,3],[2,3]))
# Out:
# [1]

# %% [markdown]
# #### 2.Find values in [5,6,7] not in [7,8,9].

# %%
print(np.setdiff1d([5,6,7],[7,8,9]))
# Out:
# [5 6]

# %% [markdown]
# #### 3.Find difference [10,20,30] minus [20].

# %%
print(np.setdiff1d([10,20,30],[20]))
# Out:
# [10 30]

# %% [markdown]
# #### 4. Find unique elements in [1,2,3] not in [3].

# %%
print(np.setdiff1d([1,2,3],[3]))
# Out:
# [1 2]

# %% [markdown]
# #### 5. Find elements in [100,200] not in [200].

# %%
print(np.setdiff1d([100,200],[200]))
# Out:
# [100]

# %% [markdown]
# #### 6. Find difference [2,4,6] minus [4].

# %%
print(np.setdiff1d([2,4,6],[4]))
# Out:
# [2 6]

# %% [markdown]
# #### 7. Find values in [-1,-2] not in [-2].

# %%
print(np.setdiff1d([-1,-2],[-2]))
# Out:
# [-1]

# %% [markdown]
# #### 8. Find difference [0,1,2] minus [1].

# %%
print(np.setdiff1d([0,1,2],[1]))
# Out:
# [0 2]

# %% [markdown]
# #### 9.Find elements in [9,8,7] not in [7].

# %%
print(np.setdiff1d([9,8,7],[7]))
# Out:
# [8 9]

# %% [markdown]
# #### 10.Find values in [11,12,13] not in [12].

# %%
print(np.setdiff1d([11,12,13],[12]))
# Out:
# [11 13]

# %% [markdown]
# #

# %% [markdown]
# ## 4. np.setxor1d()

# %% [markdown]
# #### 1.Find symmetric difference of [1,2,3] and [2,3,4].

# %%
print(np.setxor1d([1,2,3],[2,3,4]))
# Out:
# [1 4]

# %% [markdown]
# #### 2.Find elements only in one of [5,6,7] and [7,8,9].

# %%
print(np.setxor1d([5,6,7],[7,8,9]))
# Out:
# [5 6 8 9]

# %% [markdown]
# #### 3.Find XOR of [10,20,30] and [20,40].

# %%
print(np.setxor1d([10,20,30],[20,40]))
# Out:
# [10 30 40]

# %% [markdown]
# #### 4.Find unique non-common elements in [1,2,3] and [3,4,5].

# %%
print(np.setxor1d([1,2,3],[3,4,5]))
# Out:
# [1 2 4 5]

# %% [markdown]
# #### 5.Find XOR of [100,200] and [200,300].

# %%
print(np.setxor1d([100,200],[200,300]))
# Out:
# [100 300]

# %% [markdown]
# #### 6.Find symmetric difference of [2,4,6] and [4,8].

# %%
print(np.setxor1d([2,4,6],[4,8]))
# Out:
# [2 6 8]

# %% [markdown]
# #### 7.Find XOR of [-1,-2] and [-2,-3].

# %%
print(np.setxor1d([-1,-2],[-2,-3]))
# Out:
# [-3 -1]

# %% [markdown]
# #### 8.Find symmetric difference of [0,1,2] and [2,3,4].

# %%
print(np.setxor1d([0,1,2],[2,3,4]))
# Out:
# [0 1 3 4]

# %% [markdown]
# #### 9.Find XOR of [9,8,7] and [7,6,5].

# %%
print(np.setxor1d([9,8,7],[7,6,5]))
# Out:
# [5 6 8 9]

# %% [markdown]
# #### 10. Find symmetric difference of [11,12] and [12,13,14].

# %%
print(np.setxor1d([11,12],[12,13,14]))
# Out:
# [11 13 14]

# %% [markdown]
# #

# %% [markdown]
# ## 5. np.unique()

# %% [markdown]
# #### 1. Find unique elements in [1,2,2,3,3].

# %%
print(np.unique([1,2,2,3,3]))
# Out:
# [1 2 3]

# %% [markdown]
# #### 2. Remove duplicates from [5,5,6,7].

# %%
b = np.array([5,5,6,7])
print(np.unique(b))
# Out:
# [5 6 7]

# %% [markdown]
# #### 3. Find unique values in [10,20,20,30].

# %%
c  = np.array([10,20,20,30])
print(np.unique(c))
# Out:
# [10 20 30]

# %% [markdown]
# #### 4. Remove duplicates from [1,1,1,2].

# %%
d = np.array([1,1,1,2])
print(np.unique(d))
# Out:
# [1 2]

# %% [markdown]
# #### 5. Find unique elements in [100,200,200].

# %%
e= np.array([100,200,200])
print(np.unique(e))
# Out:
# [100 200]

# %% [markdown]
# #### 6. Remove duplicates from [2,4,4,6].

# %%
f = np.array([2,4,4,6])
print(np.unique(f))
# Out:
# [2 4 6]

# %% [markdown]
# #### 7. Find unique values in [-1,-1,-2].

# %%
g = np.array( [-1,-1,-2])
print(np.unique(g ))
# Out:
# [-2 -1]

# %% [markdown]
# #### 8. Remove duplicates from [0,0,1,2].

# %%
h= np.array( [0,0,1,2])
print(np.unique(h))
# Out:
# [0 1 2]

# %% [markdown]
# #### 9.  Find unique elements in [9,9,8,7].

# %%
i= np.array([9,9,8,7])
print(np.unique(i))
# Out:
# [7 8 9]

# %% [markdown]
# #### 10. Remove duplicates from [11,12,12,13].

# %%
j = np.array([11,12,12,13])
print(np.unique(j))
# Out:
# [11 12 13]

# %% [markdown]
# #

# %% [markdown]
# ## 6. np.isin()

# %% [markdown]
# #### 1.Check if [1,2,3] elements exist in [2,3,4].

# %%
a1 = np.array([1,2,3])
b1 = np.array([2,3,4])
print(np.isin(a1,b1))
# Out:
# [False  True  True]

# %% [markdown]
# #### 2. Check membership of [5,6,7] in [7,8,9].

# %%
a2 = np.array([5,6,7])
b2 = np.array([7,8,9])
print(np.isin(a2,b2))
# Out:
# [False False  True]

# %% [markdown]
# #### 3. Check if [10,20] is in [20,30].

# %%
a3 = np.array([10,20])
b3 = np.array([20,30])
print(np.isin(a3,b3))
# Out:
# [False  True]

# %% [markdown]
# #### 4. Check membership of [1,2,3] in [3,4,5].

# %%
a4 = np.array([1,2,3])
b4 = np.array([3,4,5])
print(np.isin(a4,b4))
# Out:
# [False False  True]

# %% [markdown]
# #### 5. Check if [100,200] is in [200,300].

# %%
a5 = np.array([100,200] )
b5 = np.array([200,300])
print(np.isin(a5,b5))
# Out:
# [False  True]

# %% [markdown]
# #### 6. Check [2,4,6] in [1,3,5].

# %%
a6 = np.array([2,4,6])
b6 = np.array([1,3,5])
print(np.isin(a6,b6))
# Out:
# [False False False]

# %% [markdown]
# #### 7. Check membership of [-1,-2] in [-2,-3].

# %%
a7 = np.array( [-1,-2])
b7 = np.array([-2,-3])
print(np.isin(a7,b7))
# Out:
# [False  True]

# %% [markdown]
# #### 8. Check [0,1,2] in [2,3,4].

# %%
a8 = np.array([0,1,2] )
b8 = np.array([2,3,4])
print(np.isin(a8,b8))
# Out:
# [False False  True]

# %% [markdown]
# #### 9. Check [9,8,7] in [7,6,5].

# %%
a9 = np.array([9,8,7])
b9= np.array([7,6,5])
print(np.isin(a9,b9))
# Out:
# [False False  True]

# %% [markdown]
# #### 10. Check [11,12] in [12,13,14].

# %%
a10 = np.array([11,12])
b10 = np.array([12,13,14])
print(np.isin(a10,b10))
# Out:
# [False  True]
