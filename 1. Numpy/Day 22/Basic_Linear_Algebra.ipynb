# %% [markdown]
# # Basic Linear Algebra

# %% [markdown]
# ## Set 1

# %%
import numpy as np

# %% [markdown]
# #### 1. Create a vector [1,2,3] and print it.

# %%
vect = np.array([1,2,3])
vect
# Out:
# array([1, 2, 3])

# %% [markdown]
# #### 2. Create a 2×2 matrix and display its shape.

# %%
matrix = np.array([[1,2],[3,4]])
matrix
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
matrix.shape
# Out:
# (2, 2)

# %% [markdown]
# #### 3. Transpose of a 2x2 matrix

# %%
matrix.T
# Out:
# array([[1, 3],
#        [2, 4]])

# %% [markdown]
# #### 4. Dot product of [2,3] and [4,5]

# %%
v1 = np.array([2,3])
v2 = np.array([4,5])

# %%
print(np.dot(v1,v2))
# Out:
# 23

# %% [markdown]
# #### 5. Perform matrix multiplication of two 2×2 matrices.

# %%
np.random.seed(21)
m1 = np.random.randint(1,10,(2,2))
m2 = np.random.randint(2,10,(2,2))
print(m1)
# Out:
# [[9 5]
#  [1 1]]

# %%
print(m2)
# Out:
# [[2 5]
#  [6 4]]

# %%
matrix_multi = m1 @m2

# %%
matrix_multi
# Out:
# array([[48, 65],
#        [ 8,  9]], dtype=int32)

# %%
np.matmul(m1,m2)
# Out:
# array([[48, 65],
#        [ 8,  9]], dtype=int32)

# %% [markdown]
# #### 6. Determinant of a 2x2 matrix

# %%
m1
# Out:
# array([[9, 5],
#        [1, 1]], dtype=int32)

# %%
print(np.round(np.linalg.det(m1)))
# Out:
# 4.0

# %% [markdown]
# #### 7. Find inverse of a 2×2 matrix.

# %%
np.linalg.inv(m1)
# Out:
# array([[ 0.25, -1.25],
#        [-0.25,  2.25]])

# %% [markdown]
# #### 8. Compute rank of a 2×2 matrix.

# %%
np.linalg.matrix_rank(m1)
# Out:
# np.int64(2)

# %% [markdown]
# #

# %% [markdown]
# #### Set 2

# %% [markdown]
# #### 1. Create a 3×3 matrix and find its transpose.

# %%
np.random.seed(42)
ma1 = np.random.randint(1,20,(3,3))

# %%
ma1.shape
# Out:
# (3, 3)

# %% [markdown]
# #### 2. Compute dot product of [1,2,3] and [3,2,1].

# %%
va1 = np.array([1,2,3])
va2 = np.array([3,2,1])

# %%
np.dot(va1,va2)
# Out:
# np.int64(10)

# %% [markdown]
# #### 3. Multiply a matrix with its transpose.

# %%
ma1
# Out:
# array([[ 7, 15, 11],
#        [ 8,  7, 19],
#        [11, 11,  4]], dtype=int32)

# %%
print(np.multiply(ma1,ma1.T))
# Out:
# [[ 49 120 121]
#  [120  49 209]
#  [121 209  16]]

# %% [markdown]
# #### 4. Find determinant of a 3×3 matrix.

# %%
print(np.round(np.linalg.det(ma1)))
# Out:
# 1509.0

# %% [markdown]
# #### 5. Check if matrix is invertible using determinant.

# %%
if np.linalg.det(ma1) > 0:
    print(np.linalg.inv(ma1))
else:
    print("INVERSE NOT POSSIBLE")
# Out:
# [[-0.11994698  0.04042412  0.13783963]
#  [ 0.11729622 -0.06163022 -0.02982107]
#  [ 0.0072896   0.05831677 -0.04705103]]

# %% [markdown]
# #### 6. Find inverse of a valid 2×2 matrix.

# %%
m1
# Out:
# array([[9, 5],
#        [1, 1]], dtype=int32)

# %%
np.linalg.inv(m1)
# Out:
# array([[ 0.25, -1.25],
#        [-0.25,  2.25]])

# %% [markdown]
# #### 7. Compute rank of a 3×3 matrix.

# %%
np.linalg.matrix_rank(ma1)
# Out:
# np.int64(3)

# %% [markdown]
# #### 8. Compute eigenvalues of a 2×2 matrix

# %%
values, vectors = np.linalg.eig(m1)
print("Values :",values)
print("Vector :",vectors)
# Out:
# Values : [9.58257569 0.41742431]
# Vector : [[ 0.99328045 -0.5033825 ]
#  [ 0.11573221  0.86406369]]

# %% [markdown]
# #

# %% [markdown]
# # Set 3

# %% [markdown]
# #### 1. Create two matrices and perform matrix matmultiplication

# %%
np.random.seed(42)
mtx1 = np.random.randint(1,25,(3,3))
mtx2 = np.random.randint(1,30,(3,3))
print("-----------Matrix 1 -------------")
print(mtx1)
print("-----------Matrix 2 -------------")
print(mtx2)
# Out:
# -----------Matrix 1 -------------
# [[ 7 20 15]
#  [11  8 21]
#  [ 7 19 23]]
# -----------Matrix 2 -------------
# [[11 11 24]
#  [21  4  8]
#  [24  3 22]]

# %%
np.matmul(mtx1,mtx2)
# Out:
# array([[ 857,  202,  658],
#        [ 793,  216,  790],
#        [1028,  222,  826]], dtype=int32)

# %%
mtx1@mtx2
# Out:
# array([[ 857,  202,  658],
#        [ 793,  216,  790],
#        [1028,  222,  826]], dtype=int32)

# %% [markdown]
# #### 2. Compute dot product of first row of first matrix  with first column of secound matrix

# %%
np.dot(mtx1[0],mtx2[:,0])
# Out:
# np.int32(857)

# %% [markdown]
# #### 3. Find transpose and then compute A⋅A.T

# %%
A = mtx1

# %%
A.T
# Out:
# array([[ 7, 11,  7],
#        [20,  8, 19],
#        [15, 21, 23]], dtype=int32)

# %%
np.dot(A,A.T)
# Out:
# array([[674, 552, 774],
#        [552, 626, 712],
#        [774, 712, 939]], dtype=int32)

# %% [markdown]
# #### 4. Perform matrix multiplication and handle incompatible shapes using try-except.

# %%
m1
# Out:
# array([[9, 5],
#        [1, 1]], dtype=int32)

# %%
mtx1
# Out:
# array([[ 7, 20, 15],
#        [11,  8, 21],
#        [ 7, 19, 23]], dtype=int32)

# %%
try:
    result = m1 @ mtx1
    print("Result:", result)
except ValueError as e:
    print("Error: Matrix multiplication not possible due to shape mismatch")
    print(e)
# Out:
# Error: Matrix multiplication not possible due to shape mismatch
# matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 3 is different from 2)

# %% [markdown]
# #### 5. Create a 2×2 matrix and check whether it is invertible

# %%
m1
# Out:
# array([[9, 5],
#        [1, 1]], dtype=int32)

# %%
if np.linalg.det(m1) != 0:
    print("Inverse:\n", np.linalg.inv(m1))
else:
    print("Matrix is not invertible")
# Out:
# Inverse:
#  [[ 0.25 -1.25]
#  [-0.25  2.25]]
